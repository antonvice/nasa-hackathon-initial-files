# %%
import pandas as pd
import json
import geopandas as gpd
import os
import requests
def save_data(data, filename):
    with open(filename, 'w') as f:
        json.dump(data, f)

# Function to load data from disk
def load_data(filename):
    with open(filename, 'r') as f:
        return json.load(f)
    
def infrastructure_to_gdf(data):
    features = []
    for element in data:
        if element['type'] == 'node':
            geom = gpd.points_from_xy([element['lon']], [element['lat']])
        elif 'center' in element:
            geom = gpd.points_from_xy([element['center']['lon']], [element['center']['lat']])
        else:
            continue
        features.append({
            'geometry': geom[0],
            'properties': element.get('tags', {})
        })
    return gpd.GeoDataFrame(features)

def load_all_features(sumsk_infrastructure_data, kiev_infrastructure_data):
    """
    Load all infrastructure features, print out the structure of each feature, 
    and return a unified dataframe containing the necessary attributes.
    """
    def print_feature_structure(infra_data, region):
        """
        Prints the structure of the feature data.
        """
        for element in infra_data:
            feature_type = element.get('type')
            tags = element.get('tags', {})
            print(f"Region: {region}, Feature Type: {feature_type}")
            print("Tags:", json.dumps(tags, indent=4))
            print("="*50)

    # Print structure for Sumsk infrastructure
    print("Sumsk Infrastructure Data Structure:")
    print_feature_structure(sumsk_infrastructure_data, "Sumsk")
    
    # Print structure for Kiev infrastructure
    print("\nKiev Infrastructure Data Structure:")
    print_feature_structure(kiev_infrastructure_data, "Kiev")
    
    # Convert both infrastructures into a unified GeoDataFrame
    sumsk_gdf = infrastructure_to_gdf(sumsk_infrastructure_data)
    kiev_gdf = infrastructure_to_gdf(kiev_infrastructure_data)
    
    unified_gdf = pd.concat([sumsk_gdf, kiev_gdf], ignore_index=True)
    
    return unified_gdf

def prepare_unified_dataframe(unified_gdf):
    """
    Prepares a unified DataFrame from the GeoDataFrame for model training.
    The dataframe includes relevant features such as type, coordinates, and tags.
    """
    # Extract relevant properties for model building
    df = pd.DataFrame({
        'latitude': unified_gdf.geometry.y,
        'longitude': unified_gdf.geometry.x,
        'infrastructure_type': unified_gdf['properties'].apply(lambda x: x.get('military') or 
                                                               x.get('railway') or 
                                                               x.get('aeroway') or 
                                                               x.get('amenity', 'unknown')),
        'tags': unified_gdf['properties'].apply(json.dumps)  # Save all tags for later analysis
    })
    
    # Here, you could engineer additional features such as proximity to clusters, critical areas, etc.
    # For example, add a distance feature to a key area
    # df['distance_to_key_area'] = df.apply(lambda row: calculate_distance(row, key_area), axis=1)
    
    return df

def fetch_infrastructure_data(bbox, filename):
    if os.path.exists(filename):
        return load_data(filename)

    overpass_url = "http://overpass-api.de/api/interpreter"
    overpass_query = f"""
    [out:json];
    (
      node["military"]{bbox};
      way["military"]{bbox};
      relation["military"]{bbox};
      node["railway"="station"]{bbox};
      way["railway"="station"]{bbox};
      node["amenity"="hospital"]{bbox};
      way["amenity"="hospital"]{bbox};
      node["aeroway"="aerodrome"]{bbox};
      way["aeroway"="aerodrome"]{bbox};
    );
    out center;
    """
    response = requests.get(overpass_url, params={'data': overpass_query})
    data = response.json()
    
    save_data(data['elements'], filename)
    return data['elements']

sumsk_bbox_coords = [[50.0, 33.0], [52.0, 35.5]]
kiev_bbox_coords = [50.4, 51.553167, 29.267549, 32.161026]
sumsk_bbox = f"({sumsk_bbox_coords[0][0]},{sumsk_bbox_coords[0][1]},{sumsk_bbox_coords[1][0]},{sumsk_bbox_coords[1][1]})"
kiev_bbox = f"({kiev_bbox_coords[0]},{kiev_bbox_coords[2]},{kiev_bbox_coords[1]},{kiev_bbox_coords[3]})"
sumsk_infrastructure_data = fetch_infrastructure_data(sumsk_bbox, 'sumsk_infrastructure.json')
kiev_infrastructure_data = fetch_infrastructure_data(kiev_bbox, 'kiev_infrastructure.json')

# Load all features and inspect their structure
unified_gdf = load_all_features(sumsk_infrastructure_data, kiev_infrastructure_data)

# Prepare the unified DataFrame for model building
unified_df = prepare_unified_dataframe(unified_gdf)

# Display the first few rows of the unified DataFrame to check the structure
print("Unified DataFrame for Model Building")
print(unified_df.head())
# Out:
# Sumsk Infrastructure Data Structure:
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "327805",
#     "esr:user": "327805",
#     "express:code": "2200020",
#     "name": "\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446\u044c",
#     "name:fr": "Krolevets",
#     "name:ru": "\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446",
#     "name:uk": "\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446\u044c",
#     "network": "\u0423\u0417",
#     "operator": "\u042e\u0433\u043e-\u0417\u0430\u043f\u0430\u0434\u043d\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200020",
#     "wikidata": "Q12114968",
#     "wikipedia": "uk:\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446\u044c (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328102",
#     "express:code": "2200013",
#     "name": "\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u044c\u043a\u0430",
#     "name:ru": "\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u043a\u0430\u044f",
#     "name:uk": "\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u044c\u043a\u0430",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "old_name": "\u0412\u043e\u0440\u043e\u043d\u0456\u0437\u044c\u043a\u0430",
#     "old_name:uk": "\u0412\u043e\u0440\u043e\u043d\u0456\u0437\u044c\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200013",
#     "wikidata": "Q12160739",
#     "wikipedia": "uk:\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u044c\u043a\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328628",
#     "express:code": "2201001",
#     "name": "\u041d\u0435\u043f\u043b\u044e\u0454\u0432\u0435",
#     "name:ru": "\u041d\u0435\u043f\u043b\u044e\u0435\u0432\u043e",
#     "name:uk": "\u041d\u0435\u043f\u043b\u044e\u0454\u0432\u0435",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2201001",
#     "wikidata": "Q12133451",
#     "wikipedia": "uk:\u041d\u0435\u043f\u043b\u044e\u0454\u0432\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "disused": "yes",
#     "end_date": "2014",
#     "esr:code": "326408",
#     "esr:user": "327307",
#     "express:code": "2200315",
#     "int_name": "Volfyne",
#     "name": "\u0412\u043e\u043b\u0444\u0456\u043d\u0435",
#     "name:en": "Volfyne",
#     "name:ru": "\u0412\u043e\u043b\u0444\u0438\u043d\u043e",
#     "name:uk": "\u0412\u043e\u043b\u0444\u0456\u043d\u0435",
#     "old_name": "\u041d\u043e\u0432\u043e\u0441\u0456\u043b\u043a\u0438",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u043e-\u0417\u0430\u0445\u0456\u0434\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "photolines": "https://railwayz.info/photolines/station/1540",
#     "railway": "station",
#     "start_date": "1868",
#     "uic_ref": "2200315",
#     "wikidata": "Q13361343",
#     "wikipedia": "uk:\u0412\u043e\u043b\u0444\u0438\u043d\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "207603",
#     "name": "\u0420\u044b\u043b\u044c\u0441\u043a",
#     "railway": "station",
#     "uic_ref": "2000313"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445306",
#     "express:code": "2204450",
#     "name": "\u0421\u0443\u043c\u0438",
#     "name:en": "Sumy",
#     "name:ru": "\u0421\u0443\u043c\u044b",
#     "name:uk": "\u0421\u0443\u043c\u0438",
#     "network": "\u0423\u0417",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "wheelchair": "limited",
#     "wikidata": "Q9348123",
#     "wikipedia": "uk:\u0421\u0443\u043c\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445109",
#     "express:code": "2204496",
#     "name": "\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0435\u0432\u043a\u0430",
#     "name:uk": "\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204496",
#     "wikidata": "Q25445384",
#     "wikipedia": "uk:\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "alt_name:fr": "Gloukhov",
#     "esr:user": "328403",
#     "express:code": "2200021",
#     "name": "\u0413\u043b\u0443\u0445\u0456\u0432",
#     "name:fr": "Hloukhiv",
#     "name:ru": "\u0413\u043b\u0443\u0445\u043e\u0432",
#     "name:uk": "\u0413\u043b\u0443\u0445\u0456\u0432",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200021",
#     "wikidata": "Q12096194",
#     "wikipedia": "uk:\u0413\u043b\u0443\u0445\u0456\u0432 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "aeroway": "aerodrome",
#     "local_ref": "ZD9Y",
#     "name": "\u0410\u0435\u0440\u043e\u0434\u0440\u043e\u043c \u041b\u043e\u0445\u0432\u0438\u0446\u044f",
#     "name:en": "Lokhvitsya Airfield",
#     "name:uk": "\u0410\u0435\u0440\u043e\u0434\u0440\u043e\u043c \u041b\u043e\u0445\u0432\u0438\u0446\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f",
#     "name:ru": "\u0426\u0420\u0411",
#     "name:uk": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "internet_access": "no",
#     "name": "\u0417. \u043f. 4 \u043a\u043c.",
#     "name:uk": "\u0417. \u043f. 4 \u043a\u043c.",
#     "network": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "205909",
#     "name": "\u0428\u0435\u0440\u0435\u043a\u0438\u043d\u043e",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000284"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "207302",
#     "name": "\u0413\u043b\u0443\u0448\u043a\u043e\u0432\u043e",
#     "name:ru": "\u0413\u043b\u0443\u0448\u043a\u043e\u0432\u043e",
#     "name:uk": "\u0413\u043b\u0443\u0448\u043a\u043e\u0432\u043e",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000314"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "209609",
#     "express:code": "2002009",
#     "name": "\u0422\u0451\u0442\u043a\u0438\u043d\u043e",
#     "name:ru": "\u0422\u0451\u0442\u043a\u0438\u043d\u043e",
#     "name:uk": "\u0422\u044c\u043e\u0442\u043a\u0438\u043d\u0435",
#     "operator": "\u0420\u0416\u0414",
#     "railway": "station",
#     "uic_ref": "2002009"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446101",
#     "name": "\u041a\u0438\u0440\u0438\u043a\u0456\u0432\u043a\u0430",
#     "name:ru": "\u041a\u0438\u0440\u0438\u043a\u043e\u0432\u043a\u0430",
#     "name:uk": "\u041a\u0438\u0440\u0438\u043a\u0456\u0432\u043a\u0430",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204512",
#     "wikidata": "Q25445285",
#     "wikipedia": "uk:\u041a\u0438\u0440\u0438\u043a\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "205805",
#     "name": "\u041a\u043e\u043d\u044b\u0448\u0435\u0432\u043a\u0430",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_name": "Konischewka",
#     "uic_ref": "2000282"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "206507",
#     "name": "\u0421\u0443\u0434\u0436\u0430",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000293"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "207800",
#     "name": "\u0411\u043b\u043e\u0445\u0438\u043d\u043e",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000309"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "209810",
#     "express:code": "2002006",
#     "name": "\u041a\u0440\u0443\u043f\u0435\u0446",
#     "name:uk": "\u041a\u0440\u0443\u043f\u0435\u0446\u044c",
#     "operator": "\u0420\u0416\u0414",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2002006"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0410\u0440\u0441\u0435\u043d\u044c\u0435\u0432\u0441\u043a\u0438\u0439 \u0444\u0435\u043b\u044c\u0434\u0448\u0435\u0440\u0441\u043a\u0438\u0439 \u043f\u0443\u043d\u043a\u0442"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "addr:city": "\u041a\u043e\u0440\u0435\u043d\u0435\u0432\u043e",
#     "addr:country": "RU",
#     "addr:housenumber": "1",
#     "addr:street": "\u041a\u043e\u043c\u0441\u043e\u043c\u043e\u043b\u044c\u0441\u043a\u0430\u044f \u0443\u043b\u0438\u0446\u0430",
#     "amenity": "hospital",
#     "name": "\u041a\u043e\u0440\u0435\u043d\u0435\u0432\u0441\u043a\u0430\u044f \u0446\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430\u044f \u0440\u0430\u0439\u043e\u043d\u043d\u0430\u044f \u0431\u043e\u043b\u044c\u043d\u0438\u0446\u0430",
#     "phone": "+7 (47147) 2-15-33",
#     "website": "http://kor-crb.narod.ru/"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "433703",
#     "express:code": "2204503",
#     "name": "\u041a\u0440\u0430\u0441\u043d\u043e\u043f\u0456\u043b\u043b\u044f",
#     "name:uk": "\u041a\u0440\u0430\u0441\u043d\u043e\u043f\u0456\u043b\u043b\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204503",
#     "wikidata": "Q25445467",
#     "wikipedia": "uk:\u041a\u0440\u0430\u0441\u043d\u043e\u043f\u0456\u043b\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "433807",
#     "express:code": "2204502",
#     "name": "\u041a\u043e\u0440\u0447\u0430\u043a\u0456\u0432\u043a\u0430",
#     "name:ru": "\u041a\u043e\u0440\u0447\u0430\u043a\u043e\u0432\u043a\u0430",
#     "name:uk": "\u041a\u043e\u0440\u0447\u0430\u043a\u0456\u0432\u043a\u0430",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204502",
#     "wikidata": "Q25445459",
#     "wikipedia": "uk:\u041a\u043e\u0440\u0447\u0430\u043a\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "433826",
#     "express:code": "2204501",
#     "name": "\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u044c\u043a\u0438\u0439",
#     "name:ru": "\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u043a\u0438\u0439",
#     "name:uk": "\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u044c\u043a\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204501",
#     "wikidata": "Q25445447",
#     "wikipedia": "uk:\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u044c\u043a\u0438\u0439 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0410\u043b\u0442\u0438\u043d\u0456\u0432\u0441\u044c\u043a\u0430 \u0430\u043c\u0431\u0443\u043b\u0430\u0442\u043e\u0440\u0456\u044f \u0437\u0430\u0433\u0430\u043b\u044c\u043d\u043e\u0457 \u043f\u0440\u0430\u043a\u0442\u0438\u043a\u0438 \u0441\u0456\u043c\u0435\u0439\u043d\u043e\u0457 \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0438",
#     "name:uk": "\u0410\u043b\u0442\u0438\u043d\u0456\u0432\u0441\u044c\u043a\u0430 \u0430\u043c\u0431\u0443\u043b\u0430\u0442\u043e\u0440\u0456\u044f \u0437\u0430\u0433\u0430\u043b\u044c\u043d\u043e\u0457 \u043f\u0440\u0430\u043a\u0442\u0438\u043a\u0438 \u0441\u0456\u043c\u0435\u0439\u043d\u043e\u0457 \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0438"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u041a\u0443\u0434\u0438\u043d\u0446\u0435\u0432\u0441\u043a\u0438\u0439 \u0444\u0435\u043b\u044c\u0434\u0448\u0435\u0440\u0441\u043a\u043e-\u0430\u043a\u0443\u0448\u0435\u0440\u0441\u043a\u0438\u0439 \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0441\u043a\u0438\u0439 \u043f\u0443\u043d\u043a\u0442"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0420\u0430\u0439\u043e\u043d\u043d\u0430 \u043f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430",
#     "name:ru": "\u0420\u0430\u0439\u043e\u043d\u043d\u0430\u044f \u043f\u043e\u043b\u0438\u043a\u043b\u0438\u043d\u0438\u043a\u0430",
#     "name:uk": "\u0420\u0430\u0439\u043e\u043d\u043d\u0430 \u043f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0414\u0438\u0442\u044f\u0447\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f",
#     "name:ru": "\u0414\u0435\u0442\u0441\u043a\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#     "name:uk": "\u0414\u0438\u0442\u044f\u0447\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0425\u0456\u0440\u0443\u0440\u0433\u0456\u0447\u043d\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f",
#     "name:ru": "\u0425\u0438\u0440\u0443\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#     "name:uk": "\u0425\u0456\u0440\u0443\u0440\u0433\u0456\u0447\u043d\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0422\u0435\u0440\u0430\u043f\u0435\u0432\u0442\u0438\u0447\u043d\u0435 \u0432\u0456\u0434\u0456\u043b\u0435\u043d\u043d\u044f",
#     "name:ru": "\u0422\u0435\u0440\u0430\u043f\u0435\u0432\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#     "name:uk": "\u0422\u0435\u0440\u0430\u043f\u0435\u0432\u0442\u0438\u0447\u043d\u0435 \u0432\u0456\u0434\u0456\u043b\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "emergency": "yes",
#     "name": "\u0411\u043e\u043b\u044c\u043d\u0438\u0446\u0430 \u0438\u043c. \u0422\u0435\u0440\u0435\u0449\u0435\u043d\u043a\u043e"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446008",
#     "name": "\u0422\u0440\u043e\u0441\u0442\u044f\u043d\u0435\u0446\u044c-\u0421\u043c\u043e\u0440\u043e\u0434\u0438\u043d\u0435",
#     "name:en": "Trostianets-Smorodyne",
#     "name:uk": "\u0422\u0440\u043e\u0441\u0442\u044f\u043d\u0435\u0446\u044c-\u0421\u043c\u043e\u0440\u043e\u0434\u0438\u043d\u0435",
#     "network": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "phone": "+380 5458 61 120",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204460",
#     "wikidata": "Q12153994",
#     "wikipedia": "uk:\u0422\u0440\u043e\u0441\u0442\u044f\u043d\u0435\u0446\u044c-\u0421\u043c\u043e\u0440\u043e\u0434\u0438\u043d\u0435"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445804",
#     "express:code": "2204507",
#     "name": "\u0411\u043e\u0440\u043e\u043c\u043b\u044f",
#     "name:uk": "\u0411\u043e\u0440\u043e\u043c\u043b\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204507",
#     "wikidata": "Q25445306",
#     "wikipedia": "uk:\u0411\u043e\u0440\u043e\u043c\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445838",
#     "express:code": "2204508",
#     "name": "\u0421\u043a\u0440\u044f\u0433\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0421\u043a\u0440\u044f\u0433\u043e\u0432\u043a\u0430",
#     "name:uk": "\u0421\u043a\u0440\u044f\u0433\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204508",
#     "wikidata": "Q25445297",
#     "wikipedia": "uk:\u0421\u043a\u0440\u044f\u0433\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446027",
#     "name": "\u0411\u0430\u043a\u0438\u0440\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0411\u0430\u043a\u0438\u0440\u043e\u0432\u043a\u0430",
#     "name:uk": "\u0411\u0430\u043a\u0438\u0440\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204509",
#     "wikidata": "Q25445284",
#     "wikipedia": "uk:\u0411\u0430\u043a\u0438\u0440\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445908",
#     "express:code": "2204950",
#     "name": "\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u044c\u043a\u0430",
#     "name:ru": "\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u043a\u0430\u044f",
#     "name:uk": "\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u044c\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204950",
#     "wikidata": "Q25445349",
#     "wikipedia": "uk:\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u044c\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426704",
#     "int_name": "Sula",
#     "name": "\u0421\u0443\u043b\u0430",
#     "name:ru": "\u0421\u0443\u043b\u0430",
#     "name:uk": "\u0421\u0443\u043b\u0430",
#     "network": "\u0423\u0417",
#     "operator": "\u042e\u0436\u043d\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204520"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "206403",
#     "name": "\u041b\u043e\u043a\u0438\u043d\u0441\u043a\u0430\u044f",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000291"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329016",
#     "name": "\u0413\u0440\u0443\u0437\u044c\u043a\u0435",
#     "name:ru": "\u0413\u0440\u0443\u0437\u0441\u043a\u043e\u0435",
#     "name:uk": "\u0413\u0440\u0443\u0437\u044c\u043a\u0435",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200028",
#     "wikidata": "Q12098060",
#     "wikipedia": "uk:\u0413\u0440\u0443\u0437\u044c\u043a\u0435 (\u0437\u0443\u043f\u0438\u043d\u043d\u0438\u0439 \u043f\u0443\u043d\u043a\u0442)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329105",
#     "name": "\u041f\u0443\u0442\u0456\u0439\u0441\u044c\u043a\u0430",
#     "name:ru": "\u041f\u0443\u0442\u0435\u0439\u0441\u043a\u0430\u044f",
#     "name:uk": "\u041f\u0443\u0442\u0456\u0439\u0441\u044c\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200027",
#     "wikidata": "Q12145664",
#     "wikipedia": "uk:\u041f\u0443\u0442\u0456\u0439\u0441\u044c\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329209",
#     "express:code": "2200060",
#     "name": "\u041f\u0443\u0442\u0438\u0432\u043b\u044c",
#     "name:fr": "Poutyvl",
#     "name:ru": "\u041f\u0443\u0442\u0438\u0432\u043b\u044c",
#     "name:uk": "\u041f\u0443\u0442\u0438\u0432\u043b\u044c",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200060",
#     "wikidata": "Q12145639",
#     "wikipedia": "uk:\u041f\u0443\u0442\u0438\u0432\u043b\u044c (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446205",
#     "name": "\u041e\u0445\u0442\u0438\u0440\u043a\u0430",
#     "name:fr": "Okhtyrka",
#     "name:ru": "\u0410\u0445\u0442\u044b\u0440\u043a\u0430",
#     "name:uk": "\u041e\u0445\u0442\u0438\u0440\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204890",
#     "wikidata": "Q12137017",
#     "wikipedia": "uk:\u041e\u0445\u0442\u0438\u0440\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446309",
#     "name": "\u041a\u0443\u043f'\u0454\u0432\u0430\u0445\u0430",
#     "name:ru": "\u041a\u0443\u043f\u044c\u0435\u0432\u0430\u0445\u0430",
#     "name:uk": "\u041a\u0443\u043f'\u0454\u0432\u0430\u0445\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204514",
#     "wikidata": "Q12115859",
#     "wikipedia": "uk:\u041a\u0443\u043f'\u0454\u0432\u0430\u0445\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "445700",
#     "name": "\u041d\u0438\u0437\u0438",
#     "name:ru": "\u041d\u0438\u0437\u044b",
#     "name:uk": "\u041d\u0438\u0437\u0438",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "wikidata": "Q25445351",
#     "wikipedia": "uk:\u041d\u0438\u0437\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "445880",
#     "express:code": "2204844",
#     "name": "\u0420\u044f\u0431\u0443\u0448\u043a\u0438",
#     "name:ru": "\u0420\u044f\u0431\u0443\u0448\u043a\u0438",
#     "name:uk": "\u0420\u044f\u0431\u0443\u0448\u043a\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204844",
#     "wikidata": "Q25445308",
#     "wikipedia": "uk:\u0420\u044f\u0431\u0443\u0448\u043a\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "327913",
#     "express:code": "2200015",
#     "name": "\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u044c\u043a\u0438\u0439",
#     "name:ru": "\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u043a\u0438\u0439",
#     "name:uk": "\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u044c\u043a\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200015",
#     "wikidata": "Q12085076",
#     "wikipedia": "uk:\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u044c\u043a\u0438\u0439"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328121",
#     "express:code": "2200012",
#     "name": "\u041c\u0430\u043a\u043e\u0432\u0435",
#     "name:ru": "\u041c\u0430\u043a\u043e\u0432\u043e",
#     "name:uk": "\u041c\u0430\u043a\u043e\u0432\u0435",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200012",
#     "wikidata": "Q12120574",
#     "wikipedia": "uk:\u041c\u0430\u043a\u043e\u0432\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328600",
#     "express:code": "2200011",
#     "name": "\u042f\u043d\u043f\u0456\u043b\u044c",
#     "name:ru": "\u042f\u043d\u043f\u043e\u043b\u044c",
#     "name:uk": "\u042f\u043d\u043f\u0456\u043b\u044c",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200011",
#     "wikidata": "Q12173782",
#     "wikipedia": "uk:\u042f\u043d\u043f\u0456\u043b\u044c"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445607",
#     "express:code": "2204499",
#     "name": "\u0411\u0430\u0441\u0438",
#     "name:en": "Basy",
#     "name:ru": "\u0411\u0430\u0441\u044b",
#     "name:uk": "\u0411\u0430\u0441\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204499",
#     "wikidata": "Q25445371",
#     "wikipedia": "uk:\u0411\u0430\u0441\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "445503",
#     "express:code": "2204505",
#     "name": "\u0421\u0438\u0440\u043e\u0432\u0430\u0442\u043a\u0430",
#     "name:ru": "\u0421\u044b\u0440\u043e\u0432\u0430\u0442\u043a\u0430",
#     "name:uk": "\u0421\u0438\u0440\u043e\u0432\u0430\u0442\u043a\u0430",
#     "network": "\u0423\u0417",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "wikidata": "Q12152955",
#     "wikipedia": "uk:\u0421\u0438\u0440\u043e\u0432\u0430\u0442\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328507",
#     "name": "\u0411\u0430\u043d\u0438\u0447\u0456",
#     "name:ru": "\u0411\u0430\u043d\u0438\u0447\u0438",
#     "name:uk": "\u0411\u0430\u043d\u0438\u0447\u0456",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "wikidata": "Q12080818",
#     "wikipedia": "uk:\u0411\u0430\u043d\u0438\u0447\u0456 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "339906",
#     "express:code": "2200792",
#     "name": "\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0456\u0432\u0435\u0440\u0441\u044c\u043a\u0438\u0439",
#     "name:ru": "\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0435\u0432\u0435\u0440\u0441\u043a\u0438\u0439",
#     "name:uk": "\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0456\u0432\u0435\u0440\u0441\u044c\u043a\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2200792",
#     "wikidata": "Q12133897",
#     "wikipedia": "uk:\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0456\u0432\u0435\u0440\u0441\u044c\u043a\u0438\u0439 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328206",
#     "express:code": "2200016",
#     "name": "\u0428\u043e\u0441\u0442\u043a\u0430",
#     "name:ru": "\u0428\u043e\u0441\u0442\u043a\u0430",
#     "name:uk": "\u0428\u043e\u0441\u0442\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200016",
#     "wheelchair": "yes",
#     "wikidata": "Q12172245",
#     "wikipedia": "uk:\u0428\u043e\u0441\u0442\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329800",
#     "express:code": "2200298",
#     "name": "\u0415\u0441\u043c\u0430\u043d\u044c",
#     "name:ru": "\u042d\u0441\u043c\u0430\u043d\u044c",
#     "name:uk": "\u0415\u0441\u043c\u0430\u043d\u044c",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2200298",
#     "wikidata": "Q12104126",
#     "wikipedia": "uk:\u0415\u0441\u043c\u0430\u043d\u044c (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329232",
#     "express:code": "2200024",
#     "name": "\u041a\u043e\u0448\u0430\u0440\u0438",
#     "name:ru": "\u041a\u043e\u0448\u0430\u0440\u044b",
#     "name:uk": "\u041a\u043e\u0448\u0430\u0440\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200024",
#     "wikidata": "Q12113964",
#     "wikipedia": "uk:\u041a\u043e\u0448\u0430\u0440\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "444910",
#     "express:code": "2204495",
#     "name": "\u0410\u043c\u0431\u0430\u0440\u0438",
#     "name:ru": "\u0410\u043c\u0431\u0430\u0440\u044b",
#     "name:uk": "\u0410\u043c\u0431\u0430\u0440\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204495",
#     "wikidata": "Q25445398",
#     "wikipedia": "uk:\u0410\u043c\u0431\u0430\u0440\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445005",
#     "express:code": "2204066",
#     "name": "\u0412\u0438\u0440\u0438\u043d\u0441\u044c\u043a\u0438\u0439 \u0417\u0430\u0432\u043e\u0434",
#     "name:ru": "\u0412\u0438\u0440\u044b\u043d\u0441\u043a\u0438\u0439 \u0417\u0430\u0432\u043e\u0434",
#     "name:uk": "\u0412\u0438\u0440\u0438\u043d\u0441\u044c\u043a\u0438\u0439 \u0417\u0430\u0432\u043e\u0434",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204066"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "444905",
#     "express:code": "2204494",
#     "name": "\u0412\u0438\u0440\u0438",
#     "name:ru": "\u0412\u0438\u0440\u044b",
#     "name:uk": "\u0412\u0438\u0440\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204494",
#     "wikidata": "Q25445400",
#     "wikipedia": "uk:\u0412\u0438\u0440\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "433614",
#     "express:code": "2204177",
#     "name": "\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u0435",
#     "name:ru": "\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u043e\u0435",
#     "name:uk": "\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u0435",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204177",
#     "wikidata": "Q50407088",
#     "wikipedia": "uk:\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426502",
#     "express:code": "2204539",
#     "name": "\u0410\u043d\u0434\u0440\u0456\u044f\u0448\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0410\u043d\u0434\u0440\u0438\u044f\u0448\u0435\u0432\u043a\u0430",
#     "name:uk": "\u0410\u043d\u0434\u0440\u0456\u044f\u0448\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204539",
#     "wikidata": "Q16691853",
#     "wikipedia": "uk:\u0410\u043d\u0434\u0440\u0456\u044f\u0448\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426409",
#     "express:code": "2204537",
#     "name": "\u0411\u0456\u043b\u043e\u0432\u043e\u0434\u0438",
#     "name:ru": "\u0411\u0435\u043b\u043e\u0432\u043e\u0434\u044b",
#     "name:uk": "\u0411\u0456\u043b\u043e\u0432\u043e\u0434\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204537",
#     "wikidata": "Q16693666",
#     "wikipedia": "uk:\u0411\u0456\u043b\u043e\u0432\u043e\u0434\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426305",
#     "express:code": "2204623",
#     "name": "\u0417\u0430\u0441\u0443\u043b\u043b\u044f",
#     "name:ru": "\u0417\u0430\u0441\u0443\u043b\u044c\u0435",
#     "name:uk": "\u0417\u0430\u0441\u0443\u043b\u043b\u044f",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204623",
#     "wikidata": "Q25445542",
#     "wikipedia": "uk:\u0417\u0430\u0441\u0443\u043b\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "427100",
#     "express:code": "2204490",
#     "name": "\u0420\u043e\u0433\u0438\u043d\u0446\u0456",
#     "name:ru": "\u0420\u043e\u0433\u0438\u043d\u0446\u044b",
#     "name:uk": "\u0420\u043e\u0433\u0438\u043d\u0446\u0456",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204490",
#     "wikidata": "Q16714445",
#     "wikipedia": "uk:\u0420\u043e\u0433\u0438\u043d\u0446\u0456 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426201",
#     "express:code": "2204510",
#     "name": "\u0420\u043e\u043c\u043d\u0438",
#     "name:fr": "Romny",
#     "name:ru": "\u0420\u043e\u043c\u043d\u044b",
#     "name:uk": "\u0420\u043e\u043c\u043d\u0438",
#     "network": "\u0423\u0417",
#     "operator": "\u042e\u0436\u043d\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204510",
#     "wikidata": "Q16714685",
#     "wikipedia": "uk:\u0420\u043e\u043c\u043d\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "426108",
#     "esr:user": "426108",
#     "express:code": "2204480",
#     "express:name": "\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430",
#     "name": "\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430",
#     "name:fr": "Talala\u00efvka",
#     "name:ru": "\u0422\u0430\u043b\u0430\u043b\u0430\u0435\u0432\u043a\u0430",
#     "name:uk": "\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204480",
#     "wikidata": "Q16718987",
#     "wikipedia": "uk:\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0412\u0435\u043b\u0438\u043a\u043e\u043f\u0438\u0441\u0430\u0440\u0456\u0432\u0441\u044c\u043a\u0430 \u0426\u0420\u041b",
#     "name:ru": "\u0412\u0435\u043b\u0438\u043a\u043e\u043f\u0438\u0441\u0430\u0440\u0435\u0432\u0441\u043a\u0430\u044f \u0426\u0420\u0411",
#     "name:uk": "\u0412\u0435\u043b\u0438\u043a\u043e\u043f\u0438\u0441\u0430\u0440\u0456\u0432\u0441\u044c\u043a\u0430 \u0426\u0420\u041b"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "addr:city": "\u0421\u0443\u043c\u0438",
#     "esr:user": "445400",
#     "express:code": "2204498",
#     "name": "\u0421\u0443\u043c\u0438-\u0422\u043e\u0432\u0430\u0440\u043d\u0430",
#     "name:en": "Sumy-Tovarna",
#     "name:ru": "\u0421\u0443\u043c\u044b-\u0422\u043e\u0432\u0430\u0440\u043d\u0430\u044f",
#     "name:uk": "\u0421\u0443\u043c\u0438-\u0422\u043e\u0432\u0430\u0440\u043d\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204498",
#     "wikidata": "Q25436424",
#     "wikipedia": "uk:\u0421\u0443\u043c\u0438-\u0422\u043e\u0432\u0430\u0440\u043d\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "alt_name:fr": "Belopolie",
#     "esr:user": "444708",
#     "express:code": "2204440",
#     "name": "\u0411\u0456\u043b\u043e\u043f\u0456\u043b\u043b\u044f",
#     "name:fr": "Bilopillia",
#     "name:ru": "\u0411\u0435\u043b\u043e\u043f\u043e\u043b\u044c\u0435",
#     "name:uk": "\u0411\u0456\u043b\u043e\u043f\u0456\u043b\u043b\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204440",
#     "wikidata": "Q25445428",
#     "wikipedia": "uk:\u0411\u0456\u043b\u043e\u043f\u0456\u043b\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445202",
#     "express:code": "2204497",
#     "name": "\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u043e\u0432\u043a\u0430",
#     "name:uk": "\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204497",
#     "wikidata": "Q25445377",
#     "wikipedia": "uk:\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u0456\u0432\u043a\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "444801",
#     "express:code": "2204493",
#     "name": "\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u0438\u0439",
#     "name:ru": "\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u044b\u0439",
#     "name:uk": "\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204493",
#     "wikidata": "Q25436507",
#     "wikipedia": "uk:\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u0438\u0439"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "addr:housenumber": "16",
#     "addr:postcode": "37300",
#     "addr:street": "\u0412\u043e\u043a\u0437\u0430\u043b\u044c\u043d\u0430 \u0432\u0443\u043b\u0438\u0446\u044f",
#     "name": "\u0413\u0430\u0434\u044f\u0447 \u0456\u043c. \u0421\u0435\u0440\u0433\u0456\u0454\u043d\u043a\u0430 \u041c.\u0406.",
#     "name:uk": "\u0413\u0430\u0434\u044f\u0447 \u0456\u043c. \u0421\u0435\u0440\u0433\u0456\u0454\u043d\u043a\u0430 \u041c.\u0406.",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "official_name": "\u0413\u0430\u0434\u044f\u0447 \u0456\u043c\u0435\u043d\u0456 \u0421\u0435\u0440\u0433\u0456\u0454\u043d\u043a\u0430 \u041c\u0438\u043a\u043e\u043b\u0438 \u0406\u0432\u0430\u043d\u043e\u0432\u0438\u0447\u0430",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204544"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "425800",
#     "esr:user": "426057",
#     "express:code": "2204536",
#     "express:name": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u044f",
#     "name": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u044f",
#     "name:ru": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u0430",
#     "name:uk": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204536"
# }
# ==================================================
# ...
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u041f\u0456\u0440\u043d\u0456\u0432\u0441\u044c\u043a\u0430 \u0410\u0417\u041f\u0421\u041c",
#     "name:uk": "\u041f\u0456\u0440\u043d\u0456\u0432\u0441\u044c\u043a\u0430 \u0410\u0417\u041f\u0421\u041c"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "addr:housenumber": "5-\u0410",
#     "addr:street": "\u0411\u0440\u0430\u0442\u0438\u0441\u043b\u0430\u0432\u0441\u044c\u043a\u0430 \u0432\u0443\u043b\u0438\u0446\u044f",
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "healthcare:speciality": "cardiology",
#     "name": "\u041c\u0456\u0441\u044c\u043a\u0438\u0439 \u0446\u0435\u043d\u0442\u0440 \u0441\u0435\u0440\u0446\u044f",
#     "name:en": "Kiev City Heart Center",
#     "name:ru": "\u0413\u043e\u0440\u043e\u0434\u0441\u043a\u043e\u0439 \u0426\u0435\u043d\u0442\u0440 \u0421\u0435\u0440\u0434\u0446\u0430",
#     "name:uk": "\u041c\u0456\u0441\u044c\u043a\u0438\u0439 \u0446\u0435\u043d\u0442\u0440 \u0441\u0435\u0440\u0446\u044f",
#     "website": "http://www.heart.kiev.ua/",
#     "wheelchair": "yes",
#     "wikidata": "Q12110255",
#     "wikipedia": "uk:\u041a\u0438\u0457\u0432\u0441\u044c\u043a\u0438\u0439 \u043c\u0456\u0441\u044c\u043a\u0438\u0439 \u0426\u0435\u043d\u0442\u0440 \u0441\u0435\u0440\u0446\u044f"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "addr:housenumber": "26",
#     "addr:street": "\u041f\u043e\u043b\u0456\u0441\u044c\u043a\u0430 \u0432\u0443\u043b\u0438\u0446\u044f",
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f",
#     "name:uk": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "grass",
#     "military": "obstacle_course"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u041f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430 \u21163",
#     "name:uk": "\u041f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430 \u21163"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "addr:housenumber": "177",
#     "addr:postcode": "07401",
#     "addr:street": "\u041a\u0438\u0457\u0432\u0441\u044c\u043a\u0430 \u0432\u0443\u043b\u0438\u0446\u044f",
#     "amenity": "hospital",
#     "building": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0411\u0430\u0445\u043c\u0443\u0442\u0441\u044c\u043a\u0430 \u0431\u0430\u0433\u0430\u0442\u043e\u043f\u0440\u043e\u0444\u0456\u043b\u044c\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f \u0456\u043d\u0442\u0435\u043d\u0441\u0438\u0432\u043d\u043e\u0433\u043e \u043b\u0456\u043a\u0443\u0432\u0430\u043d\u043d\u044f",
#     "name:uk": "\u0411\u0430\u0445\u043c\u0443\u0442\u0441\u044c\u043a\u0430 \u0431\u0430\u0433\u0430\u0442\u043e\u043f\u0440\u043e\u0444\u0456\u043b\u044c\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f \u0456\u043d\u0442\u0435\u043d\u0441\u0438\u0432\u043d\u043e\u0433\u043e \u043b\u0456\u043a\u0443\u0432\u0430\u043d\u043d\u044f",
#     "operator": "\u041a\u041d\u041f \u201c\u0411\u0430\u0433\u0430\u0442\u043e\u043f\u0440\u043e\u0444\u0456\u043b\u044c\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f \u0456\u043d\u0442\u0435\u043d\u0441\u0438\u0432\u043d\u043e\u0433\u043e \u043b\u0456\u043a\u0443\u0432\u0430\u043d\u043d\u044f\u201d",
#     "operator:type": "public",
#     "phone": "+380 (67) 114 41 08;+380 (50) 060 39 90"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "building": "bunker",
#     "military": "bunker"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range",
#     "name": "\u21163. 50\u043c",
#     "name:uk": "\u21163. 50\u043c",
#     "ref": "3",
#     "surface": "ground"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range",
#     "surface": "ground"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "aeroway": "aerodrome",
#     "icao": "UKKT",
#     "name": "\u0421\u0432\u044f\u0442\u043e\u0448\u0438\u043d",
#     "name:en": "Sviatoshyn",
#     "name:uk": "\u0421\u0432\u044f\u0442\u043e\u0448\u0438\u043d",
#     "wikipedia": "uk:\u0421\u0432\u044f\u0442\u043e\u0448\u0438\u043d (\u0430\u0435\u0440\u043e\u0434\u0440\u043e\u043c)"
# }
# ==================================================
# Region: Kiev, Feature Type: relation
# Tags: {
#     "access": "private",
#     "alt_name:en": "Chernobyl Exclusion Zone",
#     "alt_name:hr": "Zona utu\u0111enosti Nuklearne elektrane \u010cornobilj",
#     "alt_name:ko": "\uccb4\ub974\ub178\ube4c \ucd9c\uc785 \ud1b5\uc81c \uad6c\uc5ed;\uccb4\ub974\ub178\ube4c \uc18c\uac1c \uad6c\uc5ed",
#     "boundary": "hazard",
#     "hazard": "nuclear",
#     "landuse": "military",
#     "military": "danger_area",
#     "name": "\u0417\u043e\u043d\u0430 \u0432\u0456\u0434\u0447\u0443\u0436\u0435\u043d\u043d\u044f \u0427\u043e\u0440\u043d\u043e\u0431\u0438\u043b\u044c\u0441\u044c\u043a\u043e\u0457 \u0410\u0415\u0421",
#     "name:ar": "\u0645\u0646\u0637\u0642\u0629 \u062a\u0634\u0631\u0646\u0648\u0628\u0644 \u0627\u0644\u0645\u062d\u0638\u0648\u0631\u0629",
#     "name:be": "\u0417\u043e\u043d\u0430 \u0430\u0434\u0447\u0443\u0436\u044d\u043d\u043d\u044f \u0427\u0430\u0440\u043d\u043e\u0431\u044b\u043b\u044c\u0441\u043a\u0430\u0439 \u0410\u042d\u0421",
#     "name:cs": "Uzav\u0159en\u00e1 z\u00f3na \u010cornobylu",
#     "name:de": "Entfremdungszone des Kernkraftwerks Tschernobyl",
#     "name:en": "Chernobyl Nuclear Power Plant Zone of Alienation",
#     "name:es": "Zona de alienaci\u00f3n de la central nuclear de Chorn\u00f3bil",
#     "name:fr": "Zone d'ali\u00e9nation de la centrale nucl\u00e9aire de Tchornobyl",
#     "name:hr": "\u010cornobiljska zona isklju\u010denja",
#     "name:hu": "Csornobil z\u00e1rt r\u00e1di\u00f3akt\u00edv z\u00f3na",
#     "name:id": "Zona Eksklusi Chornobyl",
#     "name:it": "Zona di alienazione di \u010cornobyl'",
#     "name:ko": "\ucd08\ub974\ub178\ube14 \ucd9c\uc785 \ud1b5\uc81c \uad6c\uc5ed",
#     "name:lt": "\u010cornobylio radioaktyvi zona",
#     "name:nl": "Vervreemdingszone van Tsjornobyl",
#     "name:pl": "Strefa Wykluczenia wok\u00f3\u0142 Czarnobylskiej Elektrowni J\u0105drowej",
#     "name:pt": "Zona de aliena\u00e7\u00e3o da Usina Nuclear de Chornobil",
#     "name:sk": "Uzavren\u00e1 z\u00f3na jadrovej elektr\u00e1rne v \u010cernobyle",
#     "name:uk": "\u0417\u043e\u043d\u0430 \u0432\u0456\u0434\u0447\u0443\u0436\u0435\u043d\u043d\u044f \u0427\u043e\u0440\u043d\u043e\u0431\u0438\u043b\u044c\u0441\u044c\u043a\u043e\u0457 \u0410\u0415\u0421",
#     "name:zh": "\u5207\u5c14\u8bfa\u8d1d\u5229\u6838\u7535\u7ad9\u9694\u79bb\u533a",
#     "old_name:de": "Sperrzone von Tschernobyl",
#     "old_name:en": "Chernobyl Nuclear Power Plant Zone of Alienation (Chernobyl Exclusion Zone)",
#     "old_name:fr": "Zone d'ali\u00e9nation de la centrale nucl\u00e9aire de Tchernobyl",
#     "old_name:id": "Zona Eksklusi Chernobyl",
#     "old_name:it": "Zona di alienazione di \u010cernobyl'",
#     "old_name:pt": "Zona de Exclus\u00e3o da Usina Nuclear de Chern\u00f3bil",
#     "operator": "\u0414\u0435\u0440\u0436\u0430\u0432\u043d\u0430 \u0441\u043b\u0443\u0436\u0431\u0430 \u0423\u043a\u0440\u0430\u0457\u043d\u0438 \u0437 \u043d\u0430\u0434\u0437\u0432\u0438\u0447\u0430\u0439\u043d\u0438\u0445 \u0441\u0438\u0442\u0443\u0430\u0446\u0456\u0439",
#     "operator:en": "State Emergency Service of Ukraine",
#     "operator:type": "government",
#     "operator:wikidata": "Q1711627",
#     "operator:wikipedia": "uk:\u0414\u0435\u0440\u0436\u0430\u0432\u043d\u0430 \u0441\u043b\u0443\u0436\u0431\u0430 \u0423\u043a\u0440\u0430\u0457\u043d\u0438 \u0437 \u043d\u0430\u0434\u0437\u0432\u0438\u0447\u0430\u0439\u043d\u0438\u0445 \u0441\u0438\u0442\u0443\u0430\u0446\u0456\u0439",
#     "protect_title:en": "Radiation exclusion zone",
#     "protected": "perpetuity",
#     "start_date": "1986-05-02",
#     "type": "boundary",
#     "wikidata": "Q1050926",
#     "wikipedia": "uk:\u0427\u043e\u0440\u043d\u043e\u0431\u0438\u043b\u044c\u0441\u044c\u043a\u0430 \u0437\u043e\u043d\u0430 \u0432\u0456\u0434\u0447\u0443\u0436\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Kiev, Feature Type: relation
# Tags: {
#     "access": "private",
#     "boundary": "hazard",
#     "contact:email": "info@zapovednik.by",
#     "contact:fax": "+375 2346 45240",
#     "contact:instagram": "https://www.instagram.com/polesskiy.zapovednik/",
#     "contact:ok": "https://ok.ru/polesskiy.zapovednik",
#     "contact:phone": "+375 2346 45239",
#     "contact:telegram": "https://t.me/polesskiy_zapovednik",
#     "contact:vk": "https://vk.com/polesskiy_zapovednik",
#     "contact:website": "http://www.zapovednik.by/",
#     "hazard": "nuclear",
#     "int_name": "Paleski radyjacyjna-eka\u0142ahi\u010dny zapaviednik",
#     "landuse": "military",
#     "leisure": "nature_reserve",
#     "military": "danger_area",
#     "name": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "name:be": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "name:be-tarask": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u044f\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "name:de": "Polessisches Staatliches Radio\u00f6kologisches Schutzgebiet",
#     "name:en": "Polesie Radioecological Reserve",
#     "name:fr": "R\u00e9serve radio\u00e9cologique de Pol\u00e9sie",
#     "name:lt": "Poles\u0117s radiacinis-ekologinis draustinis",
#     "name:lv": "Po\u013cesjes radi\u0101cijas-ekolo\u0123iskais rezerv\u0101ts",
#     "name:nl": "Radio-ecologisch Reservaat Polesski",
#     "name:pl": "Poleski rezerwat radiacyjno-ekologiczny",
#     "name:ru": "\u041f\u043e\u043b\u0435\u0441\u0441\u043a\u0438\u0439 \u0440\u0430\u0434\u0438\u0430\u0446\u0438\u043e\u043d\u043d\u043e-\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0435\u0434\u043d\u0438\u043a",
#     "name:uk": "\u041f\u043e\u043b\u0456\u0441\u044c\u043a\u0438\u0439 \u0440\u0430\u0434\u0456\u0430\u0446\u0456\u0439\u043d\u043e-\u0435\u043a\u043e\u043b\u043e\u0433\u0456\u0447\u043d\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0456\u0434\u043d\u0438\u043a",
#     "official_name": "\u041f\u043e\u043b\u0435\u0441\u0441\u043a\u0438\u0439 \u0433\u043e\u0441\u0443\u0434\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0439 \u0440\u0430\u0434\u0438\u0430\u0446\u0438\u043e\u043d\u043d\u043e-\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0435\u0434\u043d\u0438\u043a",
#     "official_name:be": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0434\u0437\u044f\u0440\u0436\u0430\u045e\u043d\u044b \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "protect_class": "1",
#     "protected": "perpetuity",
#     "protection_title": "\u0413\u043e\u0441\u0443\u0434\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0439 \u0440\u0430\u0434\u0438\u0430\u0446\u0438\u043e\u043d\u043d\u043e-\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0435\u0434\u043d\u0438\u043a",
#     "start_date": "1988",
#     "type": "boundary",
#     "wikidata": "Q2043162",
#     "wikipedia": "be:\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0434\u0437\u044f\u0440\u0436\u0430\u045e\u043d\u044b \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a"
# }
# ==================================================
# Region: Kiev, Feature Type: relation
# Tags: {
#     "landuse": "military",
#     "military": "checkpoint",
#     "type": "multipolygon"
# }
# ==================================================
# Unified DataFrame for Model Building
#     latitude  longitude infrastructure_type  \
# 0  51.551620  33.362626             station
# 1  51.764183  33.481377             station
# 2  51.977931  33.853519             station
# 3  51.240527  34.457664             station
# 4  51.568419  34.713039             station
#
#                                                 tags
# 0  {"esr:code": "327805", "esr:user": "327805", "...
# 1  {"esr:user": "328102", "express:code": "220001...
# 2  {"esr:user": "328628", "express:code": "220100...
# 3  {"disused": "yes", "end_date": "2014", "esr:co...
# 4  {"esr:user": "207603", "name": "\u0420\u044b\u...

# %%
def add_roads_and_convoy_data(unified_gdf, sumsk_roads_gdf, kiev_roads_gdf, convoy_gdf):
    """
    Adds roads and convoy data to the unified GeoDataFrame.
    """
    # Step 1: Combine Sumsk and Kiev roads into one GeoDataFrame
    all_roads_gdf = pd.concat([sumsk_roads_gdf, kiev_roads_gdf], ignore_index=True)
    
    # Step 2: Ensure all GeoDataFrames use the same CRS (EPSG:4326)
    if unified_gdf.crs is None:
        unified_gdf = unified_gdf.set_crs("EPSG:4326", allow_override=True)
    
    # Step 3: Add road information to unified_gdf based on proximity or intersection
    # Use a spatial join to match roads near infrastructure points (using predicate instead of op)
    roads_near_infra = gpd.sjoin(unified_gdf, all_roads_gdf, how='left', predicate='intersects')

    # Step 4: Add convoy information based on proximity (using predicate instead of op)
    convoy_near_infra = gpd.sjoin(unified_gdf, convoy_gdf, how='left', predicate='intersects')

    # Step 5: Create a unified DataFrame that includes infrastructure, road, and convoy data
    combined_df = roads_near_infra.copy()
    combined_df['convoy_present'] = ~convoy_near_infra['index_right'].isnull()  # True if a convoy is nearby

    return combined_df

# Function to create convoy GeoDataFrame
def create_convoy_gdf(convoy_data):
    """
    Converts convoy data into a GeoDataFrame for spatial operations.
    Ensures that the convoy data has a 'geometry' column with valid geometries.
    """
    # Ensure the geometry column exists
    if 'geometry' in convoy_data.columns:
        # Check if the 'geometry' column has valid Point geometries
        convoy_data['geometry'] = convoy_data['geometry'].apply(lambda x: x if isinstance(x, Point) else None)
        
        # Filter out rows without valid geometry
        convoy_data = convoy_data[convoy_data['geometry'].notnull()]
    else:
        raise KeyError("Convoy data must contain a 'geometry' column with valid spatial points.")
    
    # Convert to GeoDataFrame
    convoy_gdf = gpd.GeoDataFrame(convoy_data, geometry='geometry', crs="EPSG:4326")
    
    return convoy_gdf
def prepare_final_dataframe(unified_gdf, sumsk_roads_gdf, kiev_roads_gdf, convoy_data):
    """
    Prepares the final unified DataFrame by combining infrastructure, road, and convoy data.
    """
    # Step 1: Convert convoy data into GeoDataFrame
    convoy_gdf = create_convoy_gdf(convoy_data)

    # Step 2: Add roads and convoy data to the unified infrastructure dataframe
    final_df = add_roads_and_convoy_data(unified_gdf, sumsk_roads_gdf, kiev_roads_gdf, convoy_gdf)

    return final_df

# %%
# Load the data

def load_convoy_data():
    return gpd.read_file("fixed_convoy_data.geojson")

from shapely.geometry import box
import osmnx as ox
def get_road_network(bbox_coords, cache_file):
    if os.path.exists(cache_file):
        try:
            return ox.load_graphml(cache_file)
        except Exception as e:
            print(f"Error loading cached road network: {str(e)}")
            # If loading fails, we'll fetch the data again
    
    try:
        # Try to get the road network using OSMnx
        road_network = ox.graph_from_bbox(
            bbox_coords[3], bbox_coords[1], bbox_coords[2], bbox_coords[0],
            network_type='drive', simplify=True,
            custom_filter='["highway"~"motorway|trunk|primary|secondary"]'
        )
        # Save the road network to cache
        ox.save_graphml(road_network, cache_file)
        return road_network
    except Exception as e:
        print(f"Error fetching road network from OSM: {str(e)}")
        print("Falling back to simplified road network...")
        
        # Fallback: Create a simplified road network
        bbox = box(bbox_coords[0], bbox_coords[1], bbox_coords[2], bbox_coords[3])
        simplified_roads = gpd.GeoDataFrame(
            geometry=[bbox.boundary],
            crs="EPSG:4326"
        )
        simplified_roads['highway'] = 'primary'
        return simplified_roads

# %%
print(convoy_data.columns)
# Out:
# Index(['id', 'status', 'violenceLevel', 'url', 'type', 'geolocUrl', 'credit',
#        'description', 'areaTypeAffected', 'civCas', 'verifiedDate', 'country',
#        'province', 'district', 'city', 'isPublished', 'categories',
#        'geometry'],
#       dtype='object')

# %%
# Load the necessary data
sumsk_infrastructure_data = fetch_infrastructure_data(sumsk_bbox, 'sumsk_infrastructure.json')
kiev_infrastructure_data = fetch_infrastructure_data(kiev_bbox, 'kiev_infrastructure.json')
convoy_data = load_convoy_data()  # Assuming this returns convoy data in a DataFrame
# Check the convoy data to ensure 'geometry' contains valid geometries
from shapely.geometry import Point

# Check the convoy data to ensure 'geometry' contains valid geometries
convoy_data['geometry'] = convoy_data['geometry'].apply(lambda x: x if isinstance(x, Point) else None)

# Filter out rows without valid geometry
convoy_data = convoy_data[convoy_data['geometry'].notnull()]
# Create unified infrastructure GeoDataFrame
unified_gdf = load_all_features(sumsk_infrastructure_data, kiev_infrastructure_data)

# Get the roads data
sumsk_roads = get_road_network(sumsk_bbox_coords, 'sumsk_roads.graphml')
kiev_roads = get_road_network(kiev_bbox_coords, 'kiev_roads.graphml')

sumsk_roads_gdf = sumsk_roads if isinstance(sumsk_roads, gpd.GeoDataFrame) else ox.graph_to_gdfs(sumsk_roads, nodes=False)
kiev_roads_gdf = kiev_roads if isinstance(kiev_roads, gpd.GeoDataFrame) else ox.graph_to_gdfs(kiev_roads, nodes=False)

# Assuming `convoy_data` has been loaded with the correct structure
convoy_gdf = create_convoy_gdf(convoy_data)

# Continue with adding roads and convoy data to your unified DataFrame
final_df = prepare_final_dataframe(unified_gdf, sumsk_roads_gdf, kiev_roads_gdf, convoy_gdf)

# Display the final dataframe for model building
print("Final DataFrame with Roads and Convoy Information")
print(final_df.head())
# Out:
# Sumsk Infrastructure Data Structure:
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "327805",
#     "esr:user": "327805",
#     "express:code": "2200020",
#     "name": "\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446\u044c",
#     "name:fr": "Krolevets",
#     "name:ru": "\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446",
#     "name:uk": "\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446\u044c",
#     "network": "\u0423\u0417",
#     "operator": "\u042e\u0433\u043e-\u0417\u0430\u043f\u0430\u0434\u043d\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200020",
#     "wikidata": "Q12114968",
#     "wikipedia": "uk:\u041a\u0440\u043e\u043b\u0435\u0432\u0435\u0446\u044c (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328102",
#     "express:code": "2200013",
#     "name": "\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u044c\u043a\u0430",
#     "name:ru": "\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u043a\u0430\u044f",
#     "name:uk": "\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u044c\u043a\u0430",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "old_name": "\u0412\u043e\u0440\u043e\u043d\u0456\u0437\u044c\u043a\u0430",
#     "old_name:uk": "\u0412\u043e\u0440\u043e\u043d\u0456\u0437\u044c\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200013",
#     "wikidata": "Q12160739",
#     "wikipedia": "uk:\u0422\u0435\u0440\u0435\u0449\u0435\u043d\u0441\u044c\u043a\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328628",
#     "express:code": "2201001",
#     "name": "\u041d\u0435\u043f\u043b\u044e\u0454\u0432\u0435",
#     "name:ru": "\u041d\u0435\u043f\u043b\u044e\u0435\u0432\u043e",
#     "name:uk": "\u041d\u0435\u043f\u043b\u044e\u0454\u0432\u0435",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2201001",
#     "wikidata": "Q12133451",
#     "wikipedia": "uk:\u041d\u0435\u043f\u043b\u044e\u0454\u0432\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "disused": "yes",
#     "end_date": "2014",
#     "esr:code": "326408",
#     "esr:user": "327307",
#     "express:code": "2200315",
#     "int_name": "Volfyne",
#     "name": "\u0412\u043e\u043b\u0444\u0456\u043d\u0435",
#     "name:en": "Volfyne",
#     "name:ru": "\u0412\u043e\u043b\u0444\u0438\u043d\u043e",
#     "name:uk": "\u0412\u043e\u043b\u0444\u0456\u043d\u0435",
#     "old_name": "\u041d\u043e\u0432\u043e\u0441\u0456\u043b\u043a\u0438",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u043e-\u0417\u0430\u0445\u0456\u0434\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "photolines": "https://railwayz.info/photolines/station/1540",
#     "railway": "station",
#     "start_date": "1868",
#     "uic_ref": "2200315",
#     "wikidata": "Q13361343",
#     "wikipedia": "uk:\u0412\u043e\u043b\u0444\u0438\u043d\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "207603",
#     "name": "\u0420\u044b\u043b\u044c\u0441\u043a",
#     "railway": "station",
#     "uic_ref": "2000313"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445306",
#     "express:code": "2204450",
#     "name": "\u0421\u0443\u043c\u0438",
#     "name:en": "Sumy",
#     "name:ru": "\u0421\u0443\u043c\u044b",
#     "name:uk": "\u0421\u0443\u043c\u0438",
#     "network": "\u0423\u0417",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "wheelchair": "limited",
#     "wikidata": "Q9348123",
#     "wikipedia": "uk:\u0421\u0443\u043c\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445109",
#     "express:code": "2204496",
#     "name": "\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0435\u0432\u043a\u0430",
#     "name:uk": "\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204496",
#     "wikidata": "Q25445384",
#     "wikipedia": "uk:\u0413\u043e\u043b\u043e\u0432\u0430\u0448\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "alt_name:fr": "Gloukhov",
#     "esr:user": "328403",
#     "express:code": "2200021",
#     "name": "\u0413\u043b\u0443\u0445\u0456\u0432",
#     "name:fr": "Hloukhiv",
#     "name:ru": "\u0413\u043b\u0443\u0445\u043e\u0432",
#     "name:uk": "\u0413\u043b\u0443\u0445\u0456\u0432",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200021",
#     "wikidata": "Q12096194",
#     "wikipedia": "uk:\u0413\u043b\u0443\u0445\u0456\u0432 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "aeroway": "aerodrome",
#     "local_ref": "ZD9Y",
#     "name": "\u0410\u0435\u0440\u043e\u0434\u0440\u043e\u043c \u041b\u043e\u0445\u0432\u0438\u0446\u044f",
#     "name:en": "Lokhvitsya Airfield",
#     "name:uk": "\u0410\u0435\u0440\u043e\u0434\u0440\u043e\u043c \u041b\u043e\u0445\u0432\u0438\u0446\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f",
#     "name:ru": "\u0426\u0420\u0411",
#     "name:uk": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "internet_access": "no",
#     "name": "\u0417. \u043f. 4 \u043a\u043c.",
#     "name:uk": "\u0417. \u043f. 4 \u043a\u043c.",
#     "network": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "205909",
#     "name": "\u0428\u0435\u0440\u0435\u043a\u0438\u043d\u043e",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000284"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "207302",
#     "name": "\u0413\u043b\u0443\u0448\u043a\u043e\u0432\u043e",
#     "name:ru": "\u0413\u043b\u0443\u0448\u043a\u043e\u0432\u043e",
#     "name:uk": "\u0413\u043b\u0443\u0448\u043a\u043e\u0432\u043e",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000314"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "209609",
#     "express:code": "2002009",
#     "name": "\u0422\u0451\u0442\u043a\u0438\u043d\u043e",
#     "name:ru": "\u0422\u0451\u0442\u043a\u0438\u043d\u043e",
#     "name:uk": "\u0422\u044c\u043e\u0442\u043a\u0438\u043d\u0435",
#     "operator": "\u0420\u0416\u0414",
#     "railway": "station",
#     "uic_ref": "2002009"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446101",
#     "name": "\u041a\u0438\u0440\u0438\u043a\u0456\u0432\u043a\u0430",
#     "name:ru": "\u041a\u0438\u0440\u0438\u043a\u043e\u0432\u043a\u0430",
#     "name:uk": "\u041a\u0438\u0440\u0438\u043a\u0456\u0432\u043a\u0430",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204512",
#     "wikidata": "Q25445285",
#     "wikipedia": "uk:\u041a\u0438\u0440\u0438\u043a\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "205805",
#     "name": "\u041a\u043e\u043d\u044b\u0448\u0435\u0432\u043a\u0430",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_name": "Konischewka",
#     "uic_ref": "2000282"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "206507",
#     "name": "\u0421\u0443\u0434\u0436\u0430",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000293"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "207800",
#     "name": "\u0411\u043b\u043e\u0445\u0438\u043d\u043e",
#     "operator": "\u041e\u0410\u041e \u00ab\u0420\u0416\u0414\u00bb",
#     "operator:branch": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000309"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "209810",
#     "express:code": "2002006",
#     "name": "\u041a\u0440\u0443\u043f\u0435\u0446",
#     "name:uk": "\u041a\u0440\u0443\u043f\u0435\u0446\u044c",
#     "operator": "\u0420\u0416\u0414",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2002006"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0410\u0440\u0441\u0435\u043d\u044c\u0435\u0432\u0441\u043a\u0438\u0439 \u0444\u0435\u043b\u044c\u0434\u0448\u0435\u0440\u0441\u043a\u0438\u0439 \u043f\u0443\u043d\u043a\u0442"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "addr:city": "\u041a\u043e\u0440\u0435\u043d\u0435\u0432\u043e",
#     "addr:country": "RU",
#     "addr:housenumber": "1",
#     "addr:street": "\u041a\u043e\u043c\u0441\u043e\u043c\u043e\u043b\u044c\u0441\u043a\u0430\u044f \u0443\u043b\u0438\u0446\u0430",
#     "amenity": "hospital",
#     "name": "\u041a\u043e\u0440\u0435\u043d\u0435\u0432\u0441\u043a\u0430\u044f \u0446\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430\u044f \u0440\u0430\u0439\u043e\u043d\u043d\u0430\u044f \u0431\u043e\u043b\u044c\u043d\u0438\u0446\u0430",
#     "phone": "+7 (47147) 2-15-33",
#     "website": "http://kor-crb.narod.ru/"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "433703",
#     "express:code": "2204503",
#     "name": "\u041a\u0440\u0430\u0441\u043d\u043e\u043f\u0456\u043b\u043b\u044f",
#     "name:uk": "\u041a\u0440\u0430\u0441\u043d\u043e\u043f\u0456\u043b\u043b\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204503",
#     "wikidata": "Q25445467",
#     "wikipedia": "uk:\u041a\u0440\u0430\u0441\u043d\u043e\u043f\u0456\u043b\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "433807",
#     "express:code": "2204502",
#     "name": "\u041a\u043e\u0440\u0447\u0430\u043a\u0456\u0432\u043a\u0430",
#     "name:ru": "\u041a\u043e\u0440\u0447\u0430\u043a\u043e\u0432\u043a\u0430",
#     "name:uk": "\u041a\u043e\u0440\u0447\u0430\u043a\u0456\u0432\u043a\u0430",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204502",
#     "wikidata": "Q25445459",
#     "wikipedia": "uk:\u041a\u043e\u0440\u0447\u0430\u043a\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "433826",
#     "express:code": "2204501",
#     "name": "\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u044c\u043a\u0438\u0439",
#     "name:ru": "\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u043a\u0438\u0439",
#     "name:uk": "\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u044c\u043a\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204501",
#     "wikidata": "Q25445447",
#     "wikipedia": "uk:\u0417\u043e\u043b\u043e\u0442\u043d\u0438\u0446\u044c\u043a\u0438\u0439 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0410\u043b\u0442\u0438\u043d\u0456\u0432\u0441\u044c\u043a\u0430 \u0430\u043c\u0431\u0443\u043b\u0430\u0442\u043e\u0440\u0456\u044f \u0437\u0430\u0433\u0430\u043b\u044c\u043d\u043e\u0457 \u043f\u0440\u0430\u043a\u0442\u0438\u043a\u0438 \u0441\u0456\u043c\u0435\u0439\u043d\u043e\u0457 \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0438",
#     "name:uk": "\u0410\u043b\u0442\u0438\u043d\u0456\u0432\u0441\u044c\u043a\u0430 \u0430\u043c\u0431\u0443\u043b\u0430\u0442\u043e\u0440\u0456\u044f \u0437\u0430\u0433\u0430\u043b\u044c\u043d\u043e\u0457 \u043f\u0440\u0430\u043a\u0442\u0438\u043a\u0438 \u0441\u0456\u043c\u0435\u0439\u043d\u043e\u0457 \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0438"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u041a\u0443\u0434\u0438\u043d\u0446\u0435\u0432\u0441\u043a\u0438\u0439 \u0444\u0435\u043b\u044c\u0434\u0448\u0435\u0440\u0441\u043a\u043e-\u0430\u043a\u0443\u0448\u0435\u0440\u0441\u043a\u0438\u0439 \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u0441\u043a\u0438\u0439 \u043f\u0443\u043d\u043a\u0442"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0420\u0430\u0439\u043e\u043d\u043d\u0430 \u043f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430",
#     "name:ru": "\u0420\u0430\u0439\u043e\u043d\u043d\u0430\u044f \u043f\u043e\u043b\u0438\u043a\u043b\u0438\u043d\u0438\u043a\u0430",
#     "name:uk": "\u0420\u0430\u0439\u043e\u043d\u043d\u0430 \u043f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0414\u0438\u0442\u044f\u0447\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f",
#     "name:ru": "\u0414\u0435\u0442\u0441\u043a\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#     "name:uk": "\u0414\u0438\u0442\u044f\u0447\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0425\u0456\u0440\u0443\u0440\u0433\u0456\u0447\u043d\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f",
#     "name:ru": "\u0425\u0438\u0440\u0443\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#     "name:uk": "\u0425\u0456\u0440\u0443\u0440\u0433\u0456\u0447\u043d\u0435 \u0432\u0456\u0434\u0434\u0456\u043b\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0422\u0435\u0440\u0430\u043f\u0435\u0432\u0442\u0438\u0447\u043d\u0435 \u0432\u0456\u0434\u0456\u043b\u0435\u043d\u043d\u044f",
#     "name:ru": "\u0422\u0435\u0440\u0430\u043f\u0435\u0432\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#     "name:uk": "\u0422\u0435\u0440\u0430\u043f\u0435\u0432\u0442\u0438\u0447\u043d\u0435 \u0432\u0456\u0434\u0456\u043b\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "emergency": "yes",
#     "name": "\u0411\u043e\u043b\u044c\u043d\u0438\u0446\u0430 \u0438\u043c. \u0422\u0435\u0440\u0435\u0449\u0435\u043d\u043a\u043e"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446008",
#     "name": "\u0422\u0440\u043e\u0441\u0442\u044f\u043d\u0435\u0446\u044c-\u0421\u043c\u043e\u0440\u043e\u0434\u0438\u043d\u0435",
#     "name:en": "Trostianets-Smorodyne",
#     "name:uk": "\u0422\u0440\u043e\u0441\u0442\u044f\u043d\u0435\u0446\u044c-\u0421\u043c\u043e\u0440\u043e\u0434\u0438\u043d\u0435",
#     "network": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "phone": "+380 5458 61 120",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204460",
#     "wikidata": "Q12153994",
#     "wikipedia": "uk:\u0422\u0440\u043e\u0441\u0442\u044f\u043d\u0435\u0446\u044c-\u0421\u043c\u043e\u0440\u043e\u0434\u0438\u043d\u0435"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445804",
#     "express:code": "2204507",
#     "name": "\u0411\u043e\u0440\u043e\u043c\u043b\u044f",
#     "name:uk": "\u0411\u043e\u0440\u043e\u043c\u043b\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204507",
#     "wikidata": "Q25445306",
#     "wikipedia": "uk:\u0411\u043e\u0440\u043e\u043c\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445838",
#     "express:code": "2204508",
#     "name": "\u0421\u043a\u0440\u044f\u0433\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0421\u043a\u0440\u044f\u0433\u043e\u0432\u043a\u0430",
#     "name:uk": "\u0421\u043a\u0440\u044f\u0433\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204508",
#     "wikidata": "Q25445297",
#     "wikipedia": "uk:\u0421\u043a\u0440\u044f\u0433\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446027",
#     "name": "\u0411\u0430\u043a\u0438\u0440\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0411\u0430\u043a\u0438\u0440\u043e\u0432\u043a\u0430",
#     "name:uk": "\u0411\u0430\u043a\u0438\u0440\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204509",
#     "wikidata": "Q25445284",
#     "wikipedia": "uk:\u0411\u0430\u043a\u0438\u0440\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445908",
#     "express:code": "2204950",
#     "name": "\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u044c\u043a\u0430",
#     "name:ru": "\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u043a\u0430\u044f",
#     "name:uk": "\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u044c\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204950",
#     "wikidata": "Q25445349",
#     "wikipedia": "uk:\u041b\u0435\u0431\u0435\u0434\u0438\u043d\u0441\u044c\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426704",
#     "int_name": "Sula",
#     "name": "\u0421\u0443\u043b\u0430",
#     "name:ru": "\u0421\u0443\u043b\u0430",
#     "name:uk": "\u0421\u0443\u043b\u0430",
#     "network": "\u0423\u0417",
#     "operator": "\u042e\u0436\u043d\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204520"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "206403",
#     "name": "\u041b\u043e\u043a\u0438\u043d\u0441\u043a\u0430\u044f",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2000291"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329016",
#     "name": "\u0413\u0440\u0443\u0437\u044c\u043a\u0435",
#     "name:ru": "\u0413\u0440\u0443\u0437\u0441\u043a\u043e\u0435",
#     "name:uk": "\u0413\u0440\u0443\u0437\u044c\u043a\u0435",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200028",
#     "wikidata": "Q12098060",
#     "wikipedia": "uk:\u0413\u0440\u0443\u0437\u044c\u043a\u0435 (\u0437\u0443\u043f\u0438\u043d\u043d\u0438\u0439 \u043f\u0443\u043d\u043a\u0442)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329105",
#     "name": "\u041f\u0443\u0442\u0456\u0439\u0441\u044c\u043a\u0430",
#     "name:ru": "\u041f\u0443\u0442\u0435\u0439\u0441\u043a\u0430\u044f",
#     "name:uk": "\u041f\u0443\u0442\u0456\u0439\u0441\u044c\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200027",
#     "wikidata": "Q12145664",
#     "wikipedia": "uk:\u041f\u0443\u0442\u0456\u0439\u0441\u044c\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329209",
#     "express:code": "2200060",
#     "name": "\u041f\u0443\u0442\u0438\u0432\u043b\u044c",
#     "name:fr": "Poutyvl",
#     "name:ru": "\u041f\u0443\u0442\u0438\u0432\u043b\u044c",
#     "name:uk": "\u041f\u0443\u0442\u0438\u0432\u043b\u044c",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2200060",
#     "wikidata": "Q12145639",
#     "wikipedia": "uk:\u041f\u0443\u0442\u0438\u0432\u043b\u044c (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446205",
#     "name": "\u041e\u0445\u0442\u0438\u0440\u043a\u0430",
#     "name:fr": "Okhtyrka",
#     "name:ru": "\u0410\u0445\u0442\u044b\u0440\u043a\u0430",
#     "name:uk": "\u041e\u0445\u0442\u0438\u0440\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204890",
#     "wikidata": "Q12137017",
#     "wikipedia": "uk:\u041e\u0445\u0442\u0438\u0440\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "446309",
#     "name": "\u041a\u0443\u043f'\u0454\u0432\u0430\u0445\u0430",
#     "name:ru": "\u041a\u0443\u043f\u044c\u0435\u0432\u0430\u0445\u0430",
#     "name:uk": "\u041a\u0443\u043f'\u0454\u0432\u0430\u0445\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204514",
#     "wikidata": "Q12115859",
#     "wikipedia": "uk:\u041a\u0443\u043f'\u0454\u0432\u0430\u0445\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "445700",
#     "name": "\u041d\u0438\u0437\u0438",
#     "name:ru": "\u041d\u0438\u0437\u044b",
#     "name:uk": "\u041d\u0438\u0437\u0438",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "wikidata": "Q25445351",
#     "wikipedia": "uk:\u041d\u0438\u0437\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "445880",
#     "express:code": "2204844",
#     "name": "\u0420\u044f\u0431\u0443\u0448\u043a\u0438",
#     "name:ru": "\u0420\u044f\u0431\u0443\u0448\u043a\u0438",
#     "name:uk": "\u0420\u044f\u0431\u0443\u0448\u043a\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204844",
#     "wikidata": "Q25445308",
#     "wikipedia": "uk:\u0420\u044f\u0431\u0443\u0448\u043a\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "327913",
#     "express:code": "2200015",
#     "name": "\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u044c\u043a\u0438\u0439",
#     "name:ru": "\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u043a\u0438\u0439",
#     "name:uk": "\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u044c\u043a\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200015",
#     "wikidata": "Q12085076",
#     "wikipedia": "uk:\u0411\u0440\u044e\u043b\u043e\u0432\u0435\u0446\u044c\u043a\u0438\u0439"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328121",
#     "express:code": "2200012",
#     "name": "\u041c\u0430\u043a\u043e\u0432\u0435",
#     "name:ru": "\u041c\u0430\u043a\u043e\u0432\u043e",
#     "name:uk": "\u041c\u0430\u043a\u043e\u0432\u0435",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200012",
#     "wikidata": "Q12120574",
#     "wikipedia": "uk:\u041c\u0430\u043a\u043e\u0432\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328600",
#     "express:code": "2200011",
#     "name": "\u042f\u043d\u043f\u0456\u043b\u044c",
#     "name:ru": "\u042f\u043d\u043f\u043e\u043b\u044c",
#     "name:uk": "\u042f\u043d\u043f\u0456\u043b\u044c",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200011",
#     "wikidata": "Q12173782",
#     "wikipedia": "uk:\u042f\u043d\u043f\u0456\u043b\u044c"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445607",
#     "express:code": "2204499",
#     "name": "\u0411\u0430\u0441\u0438",
#     "name:en": "Basy",
#     "name:ru": "\u0411\u0430\u0441\u044b",
#     "name:uk": "\u0411\u0430\u0441\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204499",
#     "wikidata": "Q25445371",
#     "wikipedia": "uk:\u0411\u0430\u0441\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "445503",
#     "express:code": "2204505",
#     "name": "\u0421\u0438\u0440\u043e\u0432\u0430\u0442\u043a\u0430",
#     "name:ru": "\u0421\u044b\u0440\u043e\u0432\u0430\u0442\u043a\u0430",
#     "name:uk": "\u0421\u0438\u0440\u043e\u0432\u0430\u0442\u043a\u0430",
#     "network": "\u0423\u0417",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "wikidata": "Q12152955",
#     "wikipedia": "uk:\u0421\u0438\u0440\u043e\u0432\u0430\u0442\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328507",
#     "name": "\u0411\u0430\u043d\u0438\u0447\u0456",
#     "name:ru": "\u0411\u0430\u043d\u0438\u0447\u0438",
#     "name:uk": "\u0411\u0430\u043d\u0438\u0447\u0456",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "wikidata": "Q12080818",
#     "wikipedia": "uk:\u0411\u0430\u043d\u0438\u0447\u0456 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "339906",
#     "express:code": "2200792",
#     "name": "\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0456\u0432\u0435\u0440\u0441\u044c\u043a\u0438\u0439",
#     "name:ru": "\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0435\u0432\u0435\u0440\u0441\u043a\u0438\u0439",
#     "name:uk": "\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0456\u0432\u0435\u0440\u0441\u044c\u043a\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2200792",
#     "wikidata": "Q12133897",
#     "wikipedia": "uk:\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434-\u0421\u0456\u0432\u0435\u0440\u0441\u044c\u043a\u0438\u0439 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "328206",
#     "express:code": "2200016",
#     "name": "\u0428\u043e\u0441\u0442\u043a\u0430",
#     "name:ru": "\u0428\u043e\u0441\u0442\u043a\u0430",
#     "name:uk": "\u0428\u043e\u0441\u0442\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200016",
#     "wheelchair": "yes",
#     "wikidata": "Q12172245",
#     "wikipedia": "uk:\u0428\u043e\u0441\u0442\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329800",
#     "express:code": "2200298",
#     "name": "\u0415\u0441\u043c\u0430\u043d\u044c",
#     "name:ru": "\u042d\u0441\u043c\u0430\u043d\u044c",
#     "name:uk": "\u0415\u0441\u043c\u0430\u043d\u044c",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2200298",
#     "wikidata": "Q12104126",
#     "wikipedia": "uk:\u0415\u0441\u043c\u0430\u043d\u044c (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "329232",
#     "express:code": "2200024",
#     "name": "\u041a\u043e\u0448\u0430\u0440\u0438",
#     "name:ru": "\u041a\u043e\u0448\u0430\u0440\u044b",
#     "name:uk": "\u041a\u043e\u0448\u0430\u0440\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2200024",
#     "wikidata": "Q12113964",
#     "wikipedia": "uk:\u041a\u043e\u0448\u0430\u0440\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "444910",
#     "express:code": "2204495",
#     "name": "\u0410\u043c\u0431\u0430\u0440\u0438",
#     "name:ru": "\u0410\u043c\u0431\u0430\u0440\u044b",
#     "name:uk": "\u0410\u043c\u0431\u0430\u0440\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204495",
#     "wikidata": "Q25445398",
#     "wikipedia": "uk:\u0410\u043c\u0431\u0430\u0440\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445005",
#     "express:code": "2204066",
#     "name": "\u0412\u0438\u0440\u0438\u043d\u0441\u044c\u043a\u0438\u0439 \u0417\u0430\u0432\u043e\u0434",
#     "name:ru": "\u0412\u0438\u0440\u044b\u043d\u0441\u043a\u0438\u0439 \u0417\u0430\u0432\u043e\u0434",
#     "name:uk": "\u0412\u0438\u0440\u0438\u043d\u0441\u044c\u043a\u0438\u0439 \u0417\u0430\u0432\u043e\u0434",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204066"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "444905",
#     "express:code": "2204494",
#     "name": "\u0412\u0438\u0440\u0438",
#     "name:ru": "\u0412\u0438\u0440\u044b",
#     "name:uk": "\u0412\u0438\u0440\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204494",
#     "wikidata": "Q25445400",
#     "wikipedia": "uk:\u0412\u0438\u0440\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "433614",
#     "express:code": "2204177",
#     "name": "\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u0435",
#     "name:ru": "\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u043e\u0435",
#     "name:uk": "\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u0435",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:short": "\u0423\u0417",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:short": "\u0423\u0417",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204177",
#     "wikidata": "Q50407088",
#     "wikipedia": "uk:\u041f\u0443\u0448\u043a\u0430\u0440\u043d\u0435 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426502",
#     "express:code": "2204539",
#     "name": "\u0410\u043d\u0434\u0440\u0456\u044f\u0448\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0410\u043d\u0434\u0440\u0438\u044f\u0448\u0435\u0432\u043a\u0430",
#     "name:uk": "\u0410\u043d\u0434\u0440\u0456\u044f\u0448\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204539",
#     "wikidata": "Q16691853",
#     "wikipedia": "uk:\u0410\u043d\u0434\u0440\u0456\u044f\u0448\u0456\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426409",
#     "express:code": "2204537",
#     "name": "\u0411\u0456\u043b\u043e\u0432\u043e\u0434\u0438",
#     "name:ru": "\u0411\u0435\u043b\u043e\u0432\u043e\u0434\u044b",
#     "name:uk": "\u0411\u0456\u043b\u043e\u0432\u043e\u0434\u0438",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204537",
#     "wikidata": "Q16693666",
#     "wikipedia": "uk:\u0411\u0456\u043b\u043e\u0432\u043e\u0434\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426305",
#     "express:code": "2204623",
#     "name": "\u0417\u0430\u0441\u0443\u043b\u043b\u044f",
#     "name:ru": "\u0417\u0430\u0441\u0443\u043b\u044c\u0435",
#     "name:uk": "\u0417\u0430\u0441\u0443\u043b\u043b\u044f",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:en": "Ukrainian Railways",
#     "network:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "network:wikidata": "Q923337",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:en": "Ukrainian Railways",
#     "operator:uk": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "operator:wikidata": "Q923337",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204623",
#     "wikidata": "Q25445542",
#     "wikipedia": "uk:\u0417\u0430\u0441\u0443\u043b\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "427100",
#     "express:code": "2204490",
#     "name": "\u0420\u043e\u0433\u0438\u043d\u0446\u0456",
#     "name:ru": "\u0420\u043e\u0433\u0438\u043d\u0446\u044b",
#     "name:uk": "\u0420\u043e\u0433\u0438\u043d\u0446\u0456",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204490",
#     "wikidata": "Q16714445",
#     "wikipedia": "uk:\u0420\u043e\u0433\u0438\u043d\u0446\u0456 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "426201",
#     "express:code": "2204510",
#     "name": "\u0420\u043e\u043c\u043d\u0438",
#     "name:fr": "Romny",
#     "name:ru": "\u0420\u043e\u043c\u043d\u044b",
#     "name:uk": "\u0420\u043e\u043c\u043d\u0438",
#     "network": "\u0423\u0417",
#     "operator": "\u042e\u0436\u043d\u0430\u044f \u0436\u0435\u043b\u0435\u0437\u043d\u0430\u044f \u0434\u043e\u0440\u043e\u0433\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "uic_ref": "2204510",
#     "wikidata": "Q16714685",
#     "wikipedia": "uk:\u0420\u043e\u043c\u043d\u0438 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "426108",
#     "esr:user": "426108",
#     "express:code": "2204480",
#     "express:name": "\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430",
#     "name": "\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430",
#     "name:fr": "Talala\u00efvka",
#     "name:ru": "\u0422\u0430\u043b\u0430\u043b\u0430\u0435\u0432\u043a\u0430",
#     "name:uk": "\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204480",
#     "wikidata": "Q16718987",
#     "wikipedia": "uk:\u0422\u0430\u043b\u0430\u043b\u0430\u0457\u0432\u043a\u0430 (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "amenity": "hospital",
#     "name": "\u0412\u0435\u043b\u0438\u043a\u043e\u043f\u0438\u0441\u0430\u0440\u0456\u0432\u0441\u044c\u043a\u0430 \u0426\u0420\u041b",
#     "name:ru": "\u0412\u0435\u043b\u0438\u043a\u043e\u043f\u0438\u0441\u0430\u0440\u0435\u0432\u0441\u043a\u0430\u044f \u0426\u0420\u0411",
#     "name:uk": "\u0412\u0435\u043b\u0438\u043a\u043e\u043f\u0438\u0441\u0430\u0440\u0456\u0432\u0441\u044c\u043a\u0430 \u0426\u0420\u041b"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "addr:city": "\u0421\u0443\u043c\u0438",
#     "esr:user": "445400",
#     "express:code": "2204498",
#     "name": "\u0421\u0443\u043c\u0438-\u0422\u043e\u0432\u0430\u0440\u043d\u0430",
#     "name:en": "Sumy-Tovarna",
#     "name:ru": "\u0421\u0443\u043c\u044b-\u0422\u043e\u0432\u0430\u0440\u043d\u0430\u044f",
#     "name:uk": "\u0421\u0443\u043c\u0438-\u0422\u043e\u0432\u0430\u0440\u043d\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "public_transport": "stop_position",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204498",
#     "wikidata": "Q25436424",
#     "wikipedia": "uk:\u0421\u0443\u043c\u0438-\u0422\u043e\u0432\u0430\u0440\u043d\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "alt_name:fr": "Belopolie",
#     "esr:user": "444708",
#     "express:code": "2204440",
#     "name": "\u0411\u0456\u043b\u043e\u043f\u0456\u043b\u043b\u044f",
#     "name:fr": "Bilopillia",
#     "name:ru": "\u0411\u0435\u043b\u043e\u043f\u043e\u043b\u044c\u0435",
#     "name:uk": "\u0411\u0456\u043b\u043e\u043f\u0456\u043b\u043b\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204440",
#     "wikidata": "Q25445428",
#     "wikipedia": "uk:\u0411\u0456\u043b\u043e\u043f\u0456\u043b\u043b\u044f (\u0441\u0442\u0430\u043d\u0446\u0456\u044f)"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "445202",
#     "express:code": "2204497",
#     "name": "\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u0456\u0432\u043a\u0430",
#     "name:ru": "\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u043e\u0432\u043a\u0430",
#     "name:uk": "\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u0456\u0432\u043a\u0430",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204497",
#     "wikidata": "Q25445377",
#     "wikipedia": "uk:\u0422\u043e\u0440\u043e\u043f\u0438\u043b\u0456\u0432\u043a\u0430"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:user": "444801",
#     "express:code": "2204493",
#     "name": "\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u0438\u0439",
#     "name:ru": "\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u044b\u0439",
#     "name:uk": "\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u0438\u0439",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204493",
#     "wikidata": "Q25436507",
#     "wikipedia": "uk:\u0422\u043e\u0440\u043e\u0445\u0442\u044f\u043d\u0438\u0439"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "addr:housenumber": "16",
#     "addr:postcode": "37300",
#     "addr:street": "\u0412\u043e\u043a\u0437\u0430\u043b\u044c\u043d\u0430 \u0432\u0443\u043b\u0438\u0446\u044f",
#     "name": "\u0413\u0430\u0434\u044f\u0447 \u0456\u043c. \u0421\u0435\u0440\u0433\u0456\u0454\u043d\u043a\u0430 \u041c.\u0406.",
#     "name:uk": "\u0413\u0430\u0434\u044f\u0447 \u0456\u043c. \u0421\u0435\u0440\u0433\u0456\u0454\u043d\u043a\u0430 \u041c.\u0406.",
#     "network": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "official_name": "\u0413\u0430\u0434\u044f\u0447 \u0456\u043c\u0435\u043d\u0456 \u0421\u0435\u0440\u0433\u0456\u0454\u043d\u043a\u0430 \u041c\u0438\u043a\u043e\u043b\u0438 \u0406\u0432\u0430\u043d\u043e\u0432\u0438\u0447\u0430",
#     "operator": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430",
#     "public_transport": "station",
#     "railway": "station",
#     "train": "yes",
#     "uic_ref": "2204544"
# }
# ==================================================
# Region: Sumsk, Feature Type: node
# Tags: {
#     "esr:code": "425800",
#     "esr:user": "426057",
#     "express:code": "2204536",
#     "express:name": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u044f",
#     "name": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u044f",
#     "name:ru": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u0430",
#     "name:uk": "\u0411\u043b\u043e\u0442\u043d\u0438\u0446\u044f",
#     "operator": "\u0423\u043a\u0440\u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "owner": "\u041f\u0456\u0432\u0434\u0435\u043d\u043d\u0430 \u0437\u0430\u043b\u0456\u0437\u043d\u0438\u0446\u044f",
#     "railway": "station",
#     "uic_ref": "2204536"
# }
# ==================================================
# ...
#     "name:en": "Kiev City Heart Center",
#     "name:ru": "\u0413\u043e\u0440\u043e\u0434\u0441\u043a\u043e\u0439 \u0426\u0435\u043d\u0442\u0440 \u0421\u0435\u0440\u0434\u0446\u0430",
#     "name:uk": "\u041c\u0456\u0441\u044c\u043a\u0438\u0439 \u0446\u0435\u043d\u0442\u0440 \u0441\u0435\u0440\u0446\u044f",
#     "website": "http://www.heart.kiev.ua/",
#     "wheelchair": "yes",
#     "wikidata": "Q12110255",
#     "wikipedia": "uk:\u041a\u0438\u0457\u0432\u0441\u044c\u043a\u0438\u0439 \u043c\u0456\u0441\u044c\u043a\u0438\u0439 \u0426\u0435\u043d\u0442\u0440 \u0441\u0435\u0440\u0446\u044f"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "addr:housenumber": "26",
#     "addr:street": "\u041f\u043e\u043b\u0456\u0441\u044c\u043a\u0430 \u0432\u0443\u043b\u0438\u0446\u044f",
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f",
#     "name:uk": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430 \u0440\u0430\u0439\u043e\u043d\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "grass",
#     "military": "obstacle_course"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital",
#     "name": "\u041f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430 \u21163",
#     "name:uk": "\u041f\u043e\u043b\u0456\u043a\u043b\u0456\u043d\u0456\u043a\u0430 \u21163"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "addr:housenumber": "177",
#     "addr:postcode": "07401",
#     "addr:street": "\u041a\u0438\u0457\u0432\u0441\u044c\u043a\u0430 \u0432\u0443\u043b\u0438\u0446\u044f",
#     "amenity": "hospital",
#     "building": "hospital",
#     "healthcare": "hospital",
#     "name": "\u0411\u0430\u0445\u043c\u0443\u0442\u0441\u044c\u043a\u0430 \u0431\u0430\u0433\u0430\u0442\u043e\u043f\u0440\u043e\u0444\u0456\u043b\u044c\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f \u0456\u043d\u0442\u0435\u043d\u0441\u0438\u0432\u043d\u043e\u0433\u043e \u043b\u0456\u043a\u0443\u0432\u0430\u043d\u043d\u044f",
#     "name:uk": "\u0411\u0430\u0445\u043c\u0443\u0442\u0441\u044c\u043a\u0430 \u0431\u0430\u0433\u0430\u0442\u043e\u043f\u0440\u043e\u0444\u0456\u043b\u044c\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f \u0456\u043d\u0442\u0435\u043d\u0441\u0438\u0432\u043d\u043e\u0433\u043e \u043b\u0456\u043a\u0443\u0432\u0430\u043d\u043d\u044f",
#     "operator": "\u041a\u041d\u041f \u201c\u0411\u0430\u0433\u0430\u0442\u043e\u043f\u0440\u043e\u0444\u0456\u043b\u044c\u043d\u0430 \u043b\u0456\u043a\u0430\u0440\u043d\u044f \u0456\u043d\u0442\u0435\u043d\u0441\u0438\u0432\u043d\u043e\u0433\u043e \u043b\u0456\u043a\u0443\u0432\u0430\u043d\u043d\u044f\u201d",
#     "operator:type": "public",
#     "phone": "+380 (67) 114 41 08;+380 (50) 060 39 90"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "building": "bunker",
#     "military": "bunker"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "amenity": "hospital",
#     "healthcare": "hospital"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range",
#     "name": "\u21163. 50\u043c",
#     "name:uk": "\u21163. 50\u043c",
#     "ref": "3",
#     "surface": "ground"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range",
#     "surface": "ground"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "landuse": "military",
#     "military": "range"
# }
# ==================================================
# Region: Kiev, Feature Type: way
# Tags: {
#     "aeroway": "aerodrome",
#     "icao": "UKKT",
#     "name": "\u0421\u0432\u044f\u0442\u043e\u0448\u0438\u043d",
#     "name:en": "Sviatoshyn",
#     "name:uk": "\u0421\u0432\u044f\u0442\u043e\u0448\u0438\u043d",
#     "wikipedia": "uk:\u0421\u0432\u044f\u0442\u043e\u0448\u0438\u043d (\u0430\u0435\u0440\u043e\u0434\u0440\u043e\u043c)"
# }
# ==================================================
# Region: Kiev, Feature Type: relation
# Tags: {
#     "access": "private",
#     "alt_name:en": "Chernobyl Exclusion Zone",
#     "alt_name:hr": "Zona utu\u0111enosti Nuklearne elektrane \u010cornobilj",
#     "alt_name:ko": "\uccb4\ub974\ub178\ube4c \ucd9c\uc785 \ud1b5\uc81c \uad6c\uc5ed;\uccb4\ub974\ub178\ube4c \uc18c\uac1c \uad6c\uc5ed",
#     "boundary": "hazard",
#     "hazard": "nuclear",
#     "landuse": "military",
#     "military": "danger_area",
#     "name": "\u0417\u043e\u043d\u0430 \u0432\u0456\u0434\u0447\u0443\u0436\u0435\u043d\u043d\u044f \u0427\u043e\u0440\u043d\u043e\u0431\u0438\u043b\u044c\u0441\u044c\u043a\u043e\u0457 \u0410\u0415\u0421",
#     "name:ar": "\u0645\u0646\u0637\u0642\u0629 \u062a\u0634\u0631\u0646\u0648\u0628\u0644 \u0627\u0644\u0645\u062d\u0638\u0648\u0631\u0629",
#     "name:be": "\u0417\u043e\u043d\u0430 \u0430\u0434\u0447\u0443\u0436\u044d\u043d\u043d\u044f \u0427\u0430\u0440\u043d\u043e\u0431\u044b\u043b\u044c\u0441\u043a\u0430\u0439 \u0410\u042d\u0421",
#     "name:cs": "Uzav\u0159en\u00e1 z\u00f3na \u010cornobylu",
#     "name:de": "Entfremdungszone des Kernkraftwerks Tschernobyl",
#     "name:en": "Chernobyl Nuclear Power Plant Zone of Alienation",
#     "name:es": "Zona de alienaci\u00f3n de la central nuclear de Chorn\u00f3bil",
#     "name:fr": "Zone d'ali\u00e9nation de la centrale nucl\u00e9aire de Tchornobyl",
#     "name:hr": "\u010cornobiljska zona isklju\u010denja",
#     "name:hu": "Csornobil z\u00e1rt r\u00e1di\u00f3akt\u00edv z\u00f3na",
#     "name:id": "Zona Eksklusi Chornobyl",
#     "name:it": "Zona di alienazione di \u010cornobyl'",
#     "name:ko": "\ucd08\ub974\ub178\ube14 \ucd9c\uc785 \ud1b5\uc81c \uad6c\uc5ed",
#     "name:lt": "\u010cornobylio radioaktyvi zona",
#     "name:nl": "Vervreemdingszone van Tsjornobyl",
#     "name:pl": "Strefa Wykluczenia wok\u00f3\u0142 Czarnobylskiej Elektrowni J\u0105drowej",
#     "name:pt": "Zona de aliena\u00e7\u00e3o da Usina Nuclear de Chornobil",
#     "name:sk": "Uzavren\u00e1 z\u00f3na jadrovej elektr\u00e1rne v \u010cernobyle",
#     "name:uk": "\u0417\u043e\u043d\u0430 \u0432\u0456\u0434\u0447\u0443\u0436\u0435\u043d\u043d\u044f \u0427\u043e\u0440\u043d\u043e\u0431\u0438\u043b\u044c\u0441\u044c\u043a\u043e\u0457 \u0410\u0415\u0421",
#     "name:zh": "\u5207\u5c14\u8bfa\u8d1d\u5229\u6838\u7535\u7ad9\u9694\u79bb\u533a",
#     "old_name:de": "Sperrzone von Tschernobyl",
#     "old_name:en": "Chernobyl Nuclear Power Plant Zone of Alienation (Chernobyl Exclusion Zone)",
#     "old_name:fr": "Zone d'ali\u00e9nation de la centrale nucl\u00e9aire de Tchernobyl",
#     "old_name:id": "Zona Eksklusi Chernobyl",
#     "old_name:it": "Zona di alienazione di \u010cernobyl'",
#     "old_name:pt": "Zona de Exclus\u00e3o da Usina Nuclear de Chern\u00f3bil",
#     "operator": "\u0414\u0435\u0440\u0436\u0430\u0432\u043d\u0430 \u0441\u043b\u0443\u0436\u0431\u0430 \u0423\u043a\u0440\u0430\u0457\u043d\u0438 \u0437 \u043d\u0430\u0434\u0437\u0432\u0438\u0447\u0430\u0439\u043d\u0438\u0445 \u0441\u0438\u0442\u0443\u0430\u0446\u0456\u0439",
#     "operator:en": "State Emergency Service of Ukraine",
#     "operator:type": "government",
#     "operator:wikidata": "Q1711627",
#     "operator:wikipedia": "uk:\u0414\u0435\u0440\u0436\u0430\u0432\u043d\u0430 \u0441\u043b\u0443\u0436\u0431\u0430 \u0423\u043a\u0440\u0430\u0457\u043d\u0438 \u0437 \u043d\u0430\u0434\u0437\u0432\u0438\u0447\u0430\u0439\u043d\u0438\u0445 \u0441\u0438\u0442\u0443\u0430\u0446\u0456\u0439",
#     "protect_title:en": "Radiation exclusion zone",
#     "protected": "perpetuity",
#     "start_date": "1986-05-02",
#     "type": "boundary",
#     "wikidata": "Q1050926",
#     "wikipedia": "uk:\u0427\u043e\u0440\u043d\u043e\u0431\u0438\u043b\u044c\u0441\u044c\u043a\u0430 \u0437\u043e\u043d\u0430 \u0432\u0456\u0434\u0447\u0443\u0436\u0435\u043d\u043d\u044f"
# }
# ==================================================
# Region: Kiev, Feature Type: relation
# Tags: {
#     "access": "private",
#     "boundary": "hazard",
#     "contact:email": "info@zapovednik.by",
#     "contact:fax": "+375 2346 45240",
#     "contact:instagram": "https://www.instagram.com/polesskiy.zapovednik/",
#     "contact:ok": "https://ok.ru/polesskiy.zapovednik",
#     "contact:phone": "+375 2346 45239",
#     "contact:telegram": "https://t.me/polesskiy_zapovednik",
#     "contact:vk": "https://vk.com/polesskiy_zapovednik",
#     "contact:website": "http://www.zapovednik.by/",
#     "hazard": "nuclear",
#     "int_name": "Paleski radyjacyjna-eka\u0142ahi\u010dny zapaviednik",
#     "landuse": "military",
#     "leisure": "nature_reserve",
#     "military": "danger_area",
#     "name": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "name:be": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "name:be-tarask": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u044f\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "name:de": "Polessisches Staatliches Radio\u00f6kologisches Schutzgebiet",
#     "name:en": "Polesie Radioecological Reserve",
#     "name:fr": "R\u00e9serve radio\u00e9cologique de Pol\u00e9sie",
#     "name:lt": "Poles\u0117s radiacinis-ekologinis draustinis",
#     "name:lv": "Po\u013cesjes radi\u0101cijas-ekolo\u0123iskais rezerv\u0101ts",
#     "name:nl": "Radio-ecologisch Reservaat Polesski",
#     "name:pl": "Poleski rezerwat radiacyjno-ekologiczny",
#     "name:ru": "\u041f\u043e\u043b\u0435\u0441\u0441\u043a\u0438\u0439 \u0440\u0430\u0434\u0438\u0430\u0446\u0438\u043e\u043d\u043d\u043e-\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0435\u0434\u043d\u0438\u043a",
#     "name:uk": "\u041f\u043e\u043b\u0456\u0441\u044c\u043a\u0438\u0439 \u0440\u0430\u0434\u0456\u0430\u0446\u0456\u0439\u043d\u043e-\u0435\u043a\u043e\u043b\u043e\u0433\u0456\u0447\u043d\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0456\u0434\u043d\u0438\u043a",
#     "official_name": "\u041f\u043e\u043b\u0435\u0441\u0441\u043a\u0438\u0439 \u0433\u043e\u0441\u0443\u0434\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0439 \u0440\u0430\u0434\u0438\u0430\u0446\u0438\u043e\u043d\u043d\u043e-\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0435\u0434\u043d\u0438\u043a",
#     "official_name:be": "\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0434\u0437\u044f\u0440\u0436\u0430\u045e\u043d\u044b \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a",
#     "protect_class": "1",
#     "protected": "perpetuity",
#     "protection_title": "\u0413\u043e\u0441\u0443\u0434\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0439 \u0440\u0430\u0434\u0438\u0430\u0446\u0438\u043e\u043d\u043d\u043e-\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0437\u0430\u043f\u043e\u0432\u0435\u0434\u043d\u0438\u043a",
#     "start_date": "1988",
#     "type": "boundary",
#     "wikidata": "Q2043162",
#     "wikipedia": "be:\u041f\u0430\u043b\u0435\u0441\u043a\u0456 \u0434\u0437\u044f\u0440\u0436\u0430\u045e\u043d\u044b \u0440\u0430\u0434\u044b\u044f\u0446\u044b\u0439\u043d\u0430-\u044d\u043a\u0430\u043b\u0430\u0433\u0456\u0447\u043d\u044b \u0437\u0430\u043f\u0430\u0432\u0435\u0434\u043d\u0456\u043a"
# }
# ==================================================
# Region: Kiev, Feature Type: relation
# Tags: {
#     "landuse": "military",
#     "military": "checkpoint",
#     "type": "multipolygon"
# }
# ==================================================
# Final DataFrame with Roads and Convoy Information
#                     geometry  \
# 0  POINT (33.36263 51.55162)
# 1  POINT (33.48138 51.76418)
# 2  POINT (33.85352 51.97793)
# 3  POINT (34.45766 51.24053)
# 4  POINT (34.71304 51.56842)
#
#                                           properties  index_right osmid  ref  \
# 0  {'esr:code': '327805', 'esr:user': '327805', '...          NaN   NaN  NaN
# 1  {'esr:user': '328102', 'express:code': '220001...          NaN   NaN  NaN
# 2  {'esr:user': '328628', 'express:code': '220100...          NaN   NaN  NaN
# 3  {'disused': 'yes', 'end_date': '2014', 'esr:co...          NaN   NaN  NaN
# 4  {'esr:user': '207603', 'name': 'Рыльск', 'rail...          NaN   NaN  NaN
#
#   name highway maxspeed oneway reversed  length bridge lanes junction tunnel  \
# 0  NaN     NaN      NaN    NaN      NaN     NaN    NaN   NaN      NaN    NaN
# 1  NaN     NaN      NaN    NaN      NaN     NaN    NaN   NaN      NaN    NaN
# 2  NaN     NaN      NaN    NaN      NaN     NaN    NaN   NaN      NaN    NaN
# 3  NaN     NaN      NaN    NaN      NaN     NaN    NaN   NaN      NaN    NaN
# 4  NaN     NaN      NaN    NaN      NaN     NaN    NaN   NaN      NaN    NaN
#
#   width access  convoy_present
# 0   NaN    NaN           False
# 1   NaN    NaN           False
# 2   NaN    NaN           False
# 3   NaN    NaN           False
# 4   NaN    NaN           False
